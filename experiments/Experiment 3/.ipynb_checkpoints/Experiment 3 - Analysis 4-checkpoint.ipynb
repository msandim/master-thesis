# %%
set.seed(20)

library(dplyr)
library(caret)
library(tidyr)
library(ggplot2)
library(proxy)
#library(broom)
library(corrplot)
# Out:
# Attaching package: 'matlab'
#
# The following object is masked from 'package:stats':
#
#     reshape
#
# The following objects are masked from 'package:utils':
#
#     find, fix
#
# The following object is masked from 'package:base':
#
#     sum

# %%
supervised_algorithms <- c("CART",
                           "naiveBayes",
                           "neuralNetwork",
                           "randomForest",
                           "SVM_linear",
                           "SVM_polynomial",
                           "SVM_radial", 
                           "SVM_sigmoid")
unsupervised_algorithms <- c("DBSCAN",
                             "kmeans",
                             "LOF")

semi_supervised_algorithms <- c("oneClassSVM_linear",
                                "oneClassSVM_polynomial",
                                "oneClassSVM_radial",
                                "oneClassSVM_sigmoid")

datasets <- c(
  "dataset_aloi",
  #"dataset_glass",
  "dataset_iono",
  "dataset_kdd",
  #"dataset_lym",
  "dataset_pen",
  "dataset_shuttle",
  "dataset_waveform",
  "dataset_wbc",
  "dataset_wdbc",
  "dataset_wpbc",
  "dataset_ann",
  "dataset_arr",
  "dataset_cardio", 
  "dataset_heart",
  "dataset_hepatitis",
  "dataset_ads",
  "dataset_blocks",
  "dataset_parkinson",
  "dataset_pima",
  "dataset_spam",
  "dataset_stamps",
  "dataset_wilt")

# %% [markdown]
# # 1) Technique Performance Study

# %%
f_measure <- function(precision, recall, beta = 1)
{
  (1 + beta^2) * ((precision * recall) / ((precision * beta^2) + recall))
}

# %%
evaluation_algorithms <- read.csv("results_evaluation/algorithms_metrics_2017-06-15.csv") %>% rename(algorithm_f1 = f1,
                                                                                                    algorithm_precision = precision,
                                                                                                    algorithm_recall = recall)

# %%
evaluation_algorithms <- evaluation_algorithms %>% mutate(algorithm_f20 = f_measure(algorithm_precision,
                                                                                    algorithm_recall,
                                                                                    beta = 2),
                                                          algorithm_f05 = f_measure(algorithm_precision,
                                                                                    algorithm_recall,
                                                                                    beta = 0.5))

# %% [markdown]
# # 1.1) Best Algorithm in F1

# %%
evaluation_algorithms %>% group_by(dataset) %>% top_n(1, algorithm_f1) %>% select(-algorithm_f20, -algorithm_f05)
# Out:
#    dataset           algorithm      variant        algorithm_f1
# 1  dataset_aloi      randomForest   rf             0.5895966
# 2  dataset_iono      SVM_radial     SVM_radial     0.9331795
# 3  dataset_kdd       randomForest   rf             0.8521795
# 4  dataset_pen       neuralNetwork  mlp            1.0000000
# 5  dataset_shuttle   CART           cart           0.9000000
# 6  dataset_waveform  SVM_radial     SVM_radial     0.6000000
# 7  dataset_wbc       randomForest   rf             0.9000000
# 8  dataset_wdbc      naiveBayes     nb             0.9000000
# 9  dataset_wdbc      neuralNetwork  mlp            0.9000000
# 10 dataset_wdbc      SVM_linear     SVM_linear     0.9000000
# 11 dataset_wdbc      SVM_polynomial SVM_polynomial 0.9000000
# 12 dataset_wpbc      SVM_linear     SVM_linear     0.5355556
# 13 dataset_ann       randomForest   rf             0.9739010
# 14 dataset_arr       randomForest   rf             0.5866667
# 15 dataset_cardio    randomForest   rf             0.8990576
# 16 dataset_heart     naiveBayes     nb             0.6500000
# 17 dataset_hepatitis randomForest   rf             0.6833333
# 18 dataset_ads       randomForest   rf             0.8803406
# 19 dataset_blocks    randomForest   rf             0.8852068
# 20 dataset_parkinson SVM_linear     SVM_linear     0.9166667
# 21 dataset_parkinson SVM_polynomial SVM_polynomial 0.9166667
# 22 dataset_pima      randomForest   rf             0.5409231
# 23 dataset_spam      randomForest   rf             0.8725144
# 24 dataset_stamps    neuralNetwork  mlp            0.8857143
# 25 dataset_wilt      neuralNetwork  mlp            0.9011312
#    algorithm_precision algorithm_recall
# 1  0.6000766           0.5795629
# 2  0.9294872           0.9371795
# 3  0.8544737           0.8500000
# 4  1.0000000           1.0000000
# 5  0.9000000           0.9000000
# 6  0.6000000           0.6000000
# 7  0.9000000           0.9000000
# 8  0.9000000           0.9000000
# 9  0.9000000           0.9000000
# 10 0.9000000           0.9000000
# 11 0.9000000           0.9000000
# 12 0.5200000           0.5550000
# 13 0.9685185           0.9793850
# 14 0.5666667           0.6166667
# 15 0.9001742           0.8979675
# 16 0.6250000           0.6833333
# 17 0.6000000           0.8500000
# 18 0.8802553           0.8805556
# 19 0.8861176           0.8843137
# 20 0.9500000           0.9000000
# 21 0.9500000           0.9000000
# 22 0.5307692           0.5519231
# 23 0.8732143           0.8718254
# 24 0.8000000           1.0000000
# 25 0.8961538           0.9063077

# %%
evaluation_algorithms %>%
  filter(algorithm %in% supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f1) %>%
  select(-algorithm_f20, -algorithm_f05)
# Out:
#    dataset           algorithm      variant        algorithm_f1
# 1  dataset_aloi      randomForest   rf             0.5895966
# 2  dataset_iono      SVM_radial     SVM_radial     0.9331795
# 3  dataset_kdd       randomForest   rf             0.8521795
# 4  dataset_pen       neuralNetwork  mlp            1.0000000
# 5  dataset_shuttle   CART           cart           0.9000000
# 6  dataset_waveform  SVM_radial     SVM_radial     0.6000000
# 7  dataset_wbc       randomForest   rf             0.9000000
# 8  dataset_wdbc      naiveBayes     nb             0.9000000
# 9  dataset_wdbc      neuralNetwork  mlp            0.9000000
# 10 dataset_wdbc      SVM_linear     SVM_linear     0.9000000
# 11 dataset_wdbc      SVM_polynomial SVM_polynomial 0.9000000
# 12 dataset_wpbc      SVM_linear     SVM_linear     0.5355556
# 13 dataset_ann       randomForest   rf             0.9739010
# 14 dataset_arr       randomForest   rf             0.5866667
# 15 dataset_cardio    randomForest   rf             0.8990576
# 16 dataset_heart     naiveBayes     nb             0.6500000
# 17 dataset_hepatitis randomForest   rf             0.6833333
# 18 dataset_ads       randomForest   rf             0.8803406
# 19 dataset_blocks    randomForest   rf             0.8852068
# 20 dataset_parkinson SVM_linear     SVM_linear     0.9166667
# 21 dataset_parkinson SVM_polynomial SVM_polynomial 0.9166667
# 22 dataset_pima      randomForest   rf             0.5409231
# 23 dataset_spam      randomForest   rf             0.8725144
# 24 dataset_stamps    neuralNetwork  mlp            0.8857143
# 25 dataset_wilt      neuralNetwork  mlp            0.9011312
#    algorithm_precision algorithm_recall
# 1  0.6000766           0.5795629
# 2  0.9294872           0.9371795
# 3  0.8544737           0.8500000
# 4  1.0000000           1.0000000
# 5  0.9000000           0.9000000
# 6  0.6000000           0.6000000
# 7  0.9000000           0.9000000
# 8  0.9000000           0.9000000
# 9  0.9000000           0.9000000
# 10 0.9000000           0.9000000
# 11 0.9000000           0.9000000
# 12 0.5200000           0.5550000
# 13 0.9685185           0.9793850
# 14 0.5666667           0.6166667
# 15 0.9001742           0.8979675
# 16 0.6250000           0.6833333
# 17 0.6000000           0.8500000
# 18 0.8802553           0.8805556
# 19 0.8861176           0.8843137
# 20 0.9500000           0.9000000
# 21 0.9500000           0.9000000
# 22 0.5307692           0.5519231
# 23 0.8732143           0.8718254
# 24 0.8000000           1.0000000
# 25 0.8961538           0.9063077

# %%
evaluation_algorithms %>%
  filter(algorithm %in% unsupervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f1) %>%
  select(-algorithm_f20, -algorithm_f05)
# Out:
#    dataset           algorithm variant    algorithm_f1 algorithm_precision
# 1  dataset_aloi      LOF       lof_03     0.2068966    0.2068966
# 2  dataset_iono      kmeans    kmeans_25  0.8492063    0.8492063
# 3  dataset_kdd       kmeans    kmeans_08  0.5600000    0.5600000
# 4  dataset_pen       LOF       lof_03     0.0500000    0.0500000
# 5  dataset_pen       LOF       lof_05     0.0500000    0.0500000
# 6  dataset_pen       LOF       lof_08     0.0500000    0.0500000
# 7  dataset_pen       LOF       lof_14     0.0500000    0.0500000
# 8  dataset_pen       LOF       lof_19     0.0500000    0.0500000
# 9  dataset_shuttle   DBSCAN    dbscan_1.1 0.4905660    0.3250000
# 10 dataset_waveform  kmeans    kmeans_30  0.2100000    0.2100000
# 11 dataset_wbc       kmeans    kmeans_19  0.6000000    0.6000000
# 12 dataset_wdbc      kmeans    kmeans_30  0.7000000    0.7000000
# 13 dataset_wdbc      LOF       lof_19     0.7000000    0.7000000
# 14 dataset_wpbc      DBSCAN    dbscan_0.3 0.3836735    0.2373737
# 15 dataset_wpbc      DBSCAN    dbscan_0.5 0.3836735    0.2373737
# 16 dataset_wpbc      DBSCAN    dbscan_0.7 0.3836735    0.2373737
# 17 dataset_wpbc      DBSCAN    dbscan_0.9 0.3836735    0.2373737
# 18 dataset_wpbc      DBSCAN    dbscan_1.1 0.3836735    0.2373737
# 19 dataset_ann       DBSCAN    dbscan_1.1 0.1903213    0.1215584
# 20 dataset_arr       kmeans    kmeans_03  0.3333333    0.3333333
# 21 dataset_arr       LOF       lof_19     0.3333333    0.3333333
# 22 dataset_arr       LOF       lof_25     0.3333333    0.3333333
# 23 dataset_arr       LOF       lof_30     0.3333333    0.3333333
# 24 dataset_cardio    kmeans    kmeans_03  0.3640777    0.3640777
# 25 dataset_heart     kmeans    kmeans_14  0.3513514    0.3513514
# 26 dataset_heart     kmeans    kmeans_30  0.3513514    0.3513514
# 27 dataset_hepatitis kmeans    kmeans_25  0.3076923    0.3076923
# 28 dataset_hepatitis LOF       lof_25     0.3076923    0.3076923
# 29 dataset_hepatitis LOF       lof_30     0.3076923    0.3076923
# 30 dataset_ads       LOF       lof_30     0.3641304    0.3641304
# 31 dataset_blocks    kmeans    kmeans_03  0.6431373    0.6431373
# 32 dataset_parkinson kmeans    kmeans_08  0.6666667    0.6666667
# 33 dataset_parkinson kmeans    kmeans_14  0.6666667    0.6666667
# 34 dataset_pima      DBSCAN    dbscan_1.1 0.4079422    0.2634033
# 35 dataset_spam      DBSCAN    dbscan_1.1 0.3385614    0.2041748
# 36 dataset_stamps    DBSCAN    dbscan_1.1 0.3100000    0.1834320
# 37 dataset_wilt      LOF       lof_05     0.1517510    0.1517510
#    algorithm_recall
# 1  0.2068966
# 2  0.8492063
# 3  0.5600000
# 4  0.0500000
# 5  0.0500000
# 6  0.0500000
# 7  0.0500000
# 8  0.0500000
# 9  1.0000000
# 10 0.2100000
# 11 0.6000000
# 12 0.7000000
# 13 0.7000000
# 14 1.0000000
# 15 1.0000000
# 16 1.0000000
# 17 1.0000000
# 18 1.0000000
# 19 0.4382022
# 20 0.3333333
# 21 0.3333333
# 22 0.3333333
# 23 0.3333333
# 24 0.3640777
# 25 0.3513514
# 26 0.3513514
# 27 0.3076923
# 28 0.3076923
# 29 0.3076923
# 30 0.3641304
# 31 0.6431373
# 32 0.6666667
# 33 0.6666667
# 34 0.9040000
# 35 0.9905063
# 36 1.0000000
# 37 0.1517510

# %%
evaluation_algorithms %>%
  filter(algorithm %in% semi_supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f1) %>%
  select(-algorithm_f20, -algorithm_f05)
# Out:
#    dataset           algorithm              variant                algorithm_f1
# 1  dataset_aloi      oneClassSVM_radial     oneClassSVM_radial     0.065973082
# 2  dataset_iono      oneClassSVM_radial     oneClassSVM_radial     0.675022325
# 3  dataset_kdd       oneClassSVM_radial     oneClassSVM_radial     0.016418152
# 4  dataset_pen       oneClassSVM_polynomial oneClassSVM_polynomial 0.008027038
# 5  dataset_shuttle   oneClassSVM_radial     oneClassSVM_radial     0.049087824
# 6  dataset_waveform  oneClassSVM_radial     oneClassSVM_radial     0.087428604
# 7  dataset_wbc       oneClassSVM_radial     oneClassSVM_radial     0.169320402
# 8  dataset_wdbc      oneClassSVM_radial     oneClassSVM_radial     0.099780293
# 9  dataset_wpbc      oneClassSVM_polynomial oneClassSVM_polynomial 0.358608347
# 10 dataset_ann       oneClassSVM_radial     oneClassSVM_radial     0.202801067
# 11 dataset_arr       oneClassSVM_radial     oneClassSVM_radial     0.272868769
# 12 dataset_cardio    oneClassSVM_radial     oneClassSVM_radial     0.464353046
# 13 dataset_heart     oneClassSVM_radial     oneClassSVM_radial     0.472068633
# 14 dataset_hepatitis oneClassSVM_radial     oneClassSVM_radial     0.379935065
# 15 dataset_ads       oneClassSVM_radial     oneClassSVM_radial     0.398266347
# 16 dataset_blocks    oneClassSVM_radial     oneClassSVM_radial     0.293628608
# 17 dataset_parkinson oneClassSVM_radial     oneClassSVM_radial     0.487619048
# 18 dataset_pima      oneClassSVM_radial     oneClassSVM_radial     0.396864820
# 19 dataset_spam      oneClassSVM_radial     oneClassSVM_radial     0.455973576
# 20 dataset_stamps    oneClassSVM_radial     oneClassSVM_radial     0.282108215
# 21 dataset_wilt      oneClassSVM_linear     oneClassSVM_linear     0.173972989
#    algorithm_precision algorithm_recall
# 1  0.034984664         0.5776777
# 2  0.518401491         0.9769231
# 3  0.008277033         1.0000000
# 4  0.004029698         1.0000000
# 5  0.025233064         1.0000000
# 6  0.046215005         0.8100000
# 7  0.093453116         1.0000000
# 8  0.052559335         1.0000000
# 9  0.235025995         0.7750000
# 10 0.115936939         0.8091894
# 11 0.163381320         0.8833333
# 12 0.311806104         0.9100465
# 13 0.321856061         0.9250000
# 14 0.238174603         1.0000000
# 15 0.261059873         0.8426426
# 16 0.172214266         0.9960784
# 17 0.355000000         0.9500000
# 18 0.270175800         0.7532051
# 19 0.306859446         0.8875744
# 20 0.164941919         1.0000000
# 21 0.107084703         0.7767692

# %% [markdown]
# # 1.2) Best Algorithm in F2

# %%
evaluation_algorithms %>% group_by(dataset) %>% top_n(1, algorithm_f20) %>% select(-algorithm_f1, -algorithm_f05)
# Out:
#    dataset           algorithm          variant            algorithm_precision
# 1  dataset_aloi      randomForest       rf                 0.6000766
# 2  dataset_iono      SVM_radial         SVM_radial         0.9294872
# 3  dataset_kdd       randomForest       rf                 0.8544737
# 4  dataset_pen       neuralNetwork      mlp                1.0000000
# 5  dataset_shuttle   randomForest       rf                 0.7000000
# 6  dataset_shuttle   SVM_radial         SVM_radial         0.7000000
# 7  dataset_waveform  SVM_radial         SVM_radial         0.6000000
# 8  dataset_wbc       randomForest       rf                 0.9000000
# 9  dataset_wdbc      naiveBayes         nb                 0.9000000
# 10 dataset_wdbc      neuralNetwork      mlp                0.9000000
# 11 dataset_wdbc      SVM_linear         SVM_linear         0.9000000
# 12 dataset_wdbc      SVM_polynomial     SVM_polynomial     0.9000000
# 13 dataset_wpbc      DBSCAN             dbscan_0.3         0.2373737
# 14 dataset_wpbc      DBSCAN             dbscan_0.5         0.2373737
# 15 dataset_wpbc      DBSCAN             dbscan_0.7         0.2373737
# 16 dataset_wpbc      DBSCAN             dbscan_0.9         0.2373737
# 17 dataset_wpbc      DBSCAN             dbscan_1.1         0.2373737
# 18 dataset_ann       randomForest       rf                 0.9685185
# 19 dataset_arr       randomForest       rf                 0.5666667
# 20 dataset_cardio    randomForest       rf                 0.9001742
# 21 dataset_heart     oneClassSVM_radial oneClassSVM_radial 0.3218561
# 22 dataset_hepatitis randomForest       rf                 0.6000000
# 23 dataset_ads       randomForest       rf                 0.8802553
# 24 dataset_blocks    randomForest       rf                 0.8861176
# 25 dataset_parkinson SVM_linear         SVM_linear         0.9500000
# 26 dataset_parkinson SVM_polynomial     SVM_polynomial     0.9500000
# 27 dataset_pima      DBSCAN             dbscan_1.1         0.2634033
# 28 dataset_spam      randomForest       rf                 0.8732143
# 29 dataset_stamps    neuralNetwork      mlp                0.8000000
# 30 dataset_wilt      neuralNetwork      mlp                0.8961538
#    algorithm_recall algorithm_f20
# 1  0.5795629        0.5835527
# 2  0.9371795        0.9356309
# 3  0.8500000        0.8508910
# 4  1.0000000        1.0000000
# 5  1.0000000        0.9210526
# 6  1.0000000        0.9210526
# 7  0.6000000        0.6000000
# 8  0.9000000        0.9000000
# 9  0.9000000        0.9000000
# 10 0.9000000        0.9000000
# 11 0.9000000        0.9000000
# 12 0.9000000        0.9000000
# 13 1.0000000        0.6088083
# 14 1.0000000        0.6088083
# 15 1.0000000        0.6088083
# 16 1.0000000        0.6088083
# 17 1.0000000        0.6088083
# 18 0.9793850        0.9771923
# 19 0.6166667        0.6059730
# 20 0.8979675        0.8984080
# 21 0.9250000        0.6728295
# 22 0.8500000        0.7846154
# 23 0.8805556        0.8804955
# 24 0.8843137        0.8846739
# 25 0.9000000        0.9095745
# 26 0.9000000        0.9095745
# 27 0.9040000        0.6081808
# 28 0.8718254        0.8721028
# 29 1.0000000        0.9523810
# 30 0.9063077        0.9042586

# %%
evaluation_algorithms %>%
  filter(algorithm %in% supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f20) %>%
  select(-algorithm_f1, -algorithm_f05)
# Out:
#    dataset           algorithm      variant        algorithm_precision
# 1  dataset_aloi      randomForest   rf             0.6000766
# 2  dataset_iono      SVM_radial     SVM_radial     0.9294872
# 3  dataset_kdd       randomForest   rf             0.8544737
# 4  dataset_pen       neuralNetwork  mlp            1.0000000
# 5  dataset_shuttle   randomForest   rf             0.7000000
# 6  dataset_shuttle   SVM_radial     SVM_radial     0.7000000
# 7  dataset_waveform  SVM_radial     SVM_radial     0.6000000
# 8  dataset_wbc       randomForest   rf             0.9000000
# 9  dataset_wdbc      naiveBayes     nb             0.9000000
# 10 dataset_wdbc      neuralNetwork  mlp            0.9000000
# 11 dataset_wdbc      SVM_linear     SVM_linear     0.9000000
# 12 dataset_wdbc      SVM_polynomial SVM_polynomial 0.9000000
# 13 dataset_wpbc      SVM_linear     SVM_linear     0.5200000
# 14 dataset_ann       randomForest   rf             0.9685185
# 15 dataset_arr       randomForest   rf             0.5666667
# 16 dataset_cardio    randomForest   rf             0.9001742
# 17 dataset_heart     naiveBayes     nb             0.6250000
# 18 dataset_hepatitis randomForest   rf             0.6000000
# 19 dataset_ads       randomForest   rf             0.8802553
# 20 dataset_blocks    randomForest   rf             0.8861176
# 21 dataset_parkinson SVM_linear     SVM_linear     0.9500000
# 22 dataset_parkinson SVM_polynomial SVM_polynomial 0.9500000
# 23 dataset_pima      randomForest   rf             0.5307692
# 24 dataset_spam      randomForest   rf             0.8732143
# 25 dataset_stamps    neuralNetwork  mlp            0.8000000
# 26 dataset_wilt      neuralNetwork  mlp            0.8961538
#    algorithm_recall algorithm_f20
# 1  0.5795629        0.5835527
# 2  0.9371795        0.9356309
# 3  0.8500000        0.8508910
# 4  1.0000000        1.0000000
# 5  1.0000000        0.9210526
# 6  1.0000000        0.9210526
# 7  0.6000000        0.6000000
# 8  0.9000000        0.9000000
# 9  0.9000000        0.9000000
# 10 0.9000000        0.9000000
# 11 0.9000000        0.9000000
# 12 0.9000000        0.9000000
# 13 0.5550000        0.5476281
# 14 0.9793850        0.9771923
# 15 0.6166667        0.6059730
# 16 0.8979675        0.8984080
# 17 0.6833333        0.6708115
# 18 0.8500000        0.7846154
# 19 0.8805556        0.8804955
# 20 0.8843137        0.8846739
# 21 0.9000000        0.9095745
# 22 0.9000000        0.9095745
# 23 0.5519231        0.5475585
# 24 0.8718254        0.8721028
# 25 1.0000000        0.9523810
# 26 0.9063077        0.9042586

# %%
evaluation_algorithms %>%
  filter(algorithm %in% unsupervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f20) %>%
  select(-algorithm_f1, -algorithm_f05)
# Out:
#    dataset           algorithm variant    algorithm_precision algorithm_recall
# 1  dataset_aloi      LOF       lof_03     0.20689655          0.2068966
# 2  dataset_iono      kmeans    kmeans_25  0.84920635          0.8492063
# 3  dataset_kdd       kmeans    kmeans_08  0.56000000          0.5600000
# 4  dataset_pen       LOF       lof_03     0.05000000          0.0500000
# 5  dataset_pen       LOF       lof_05     0.05000000          0.0500000
# 6  dataset_pen       LOF       lof_08     0.05000000          0.0500000
# 7  dataset_pen       LOF       lof_14     0.05000000          0.0500000
# 8  dataset_pen       LOF       lof_19     0.05000000          0.0500000
# 9  dataset_shuttle   DBSCAN    dbscan_1.1 0.32500000          1.0000000
# 10 dataset_waveform  kmeans    kmeans_30  0.21000000          0.2100000
# 11 dataset_wbc       kmeans    kmeans_19  0.60000000          0.6000000
# 12 dataset_wdbc      kmeans    kmeans_30  0.70000000          0.7000000
# 13 dataset_wdbc      LOF       lof_19     0.70000000          0.7000000
# 14 dataset_wpbc      DBSCAN    dbscan_0.3 0.23737374          1.0000000
# 15 dataset_wpbc      DBSCAN    dbscan_0.5 0.23737374          1.0000000
# 16 dataset_wpbc      DBSCAN    dbscan_0.7 0.23737374          1.0000000
# 17 dataset_wpbc      DBSCAN    dbscan_0.9 0.23737374          1.0000000
# 18 dataset_wpbc      DBSCAN    dbscan_1.1 0.23737374          1.0000000
# 19 dataset_ann       DBSCAN    dbscan_0.7 0.09976121          0.7041199
# 20 dataset_arr       DBSCAN    dbscan_0.3 0.09963100          1.0000000
# 21 dataset_arr       DBSCAN    dbscan_0.5 0.09963100          1.0000000
# 22 dataset_arr       DBSCAN    dbscan_0.7 0.09963100          1.0000000
# 23 dataset_arr       DBSCAN    dbscan_0.9 0.09963100          1.0000000
# 24 dataset_arr       DBSCAN    dbscan_1.1 0.09963100          1.0000000
# 25 dataset_cardio    DBSCAN    dbscan_0.3 0.20000000          1.0000000
# 26 dataset_cardio    DBSCAN    dbscan_0.5 0.20000000          1.0000000
# 27 dataset_cardio    DBSCAN    dbscan_0.7 0.20000000          1.0000000
# 28 dataset_cardio    DBSCAN    dbscan_0.9 0.20000000          1.0000000
# 29 dataset_cardio    DBSCAN    dbscan_1.1 0.20000000          1.0000000
# 30 dataset_heart     DBSCAN    dbscan_0.3 0.19786096          1.0000000
# 31 dataset_heart     DBSCAN    dbscan_0.5 0.19786096          1.0000000
# 32 dataset_heart     DBSCAN    dbscan_0.7 0.19786096          1.0000000
# 33 dataset_heart     DBSCAN    dbscan_0.9 0.19786096          1.0000000
# 34 dataset_heart     DBSCAN    dbscan_1.1 0.19786096          1.0000000
# 35 dataset_hepatitis DBSCAN    dbscan_0.3 0.16250000          1.0000000
# 36 dataset_hepatitis DBSCAN    dbscan_0.5 0.16250000          1.0000000
# 37 dataset_hepatitis DBSCAN    dbscan_0.7 0.16250000          1.0000000
# 38 dataset_hepatitis DBSCAN    dbscan_0.9 0.16250000          1.0000000
# 39 dataset_hepatitis DBSCAN    dbscan_1.1 0.16250000          1.0000000
# 40 dataset_ads       DBSCAN    dbscan_0.3 0.18718210          1.0000000
# 41 dataset_ads       DBSCAN    dbscan_0.5 0.18718210          1.0000000
# 42 dataset_ads       DBSCAN    dbscan_0.7 0.18718210          1.0000000
# 43 dataset_ads       DBSCAN    dbscan_0.9 0.18718210          1.0000000
# 44 dataset_ads       DBSCAN    dbscan_1.1 0.18718210          1.0000000
# 45 dataset_blocks    kmeans    kmeans_03  0.64313725          0.6431373
# 46 dataset_parkinson kmeans    kmeans_08  0.66666667          0.6666667
# 47 dataset_parkinson kmeans    kmeans_14  0.66666667          0.6666667
# 48 dataset_pima      DBSCAN    dbscan_1.1 0.26340326          0.9040000
# 49 dataset_spam      DBSCAN    dbscan_1.1 0.20417482          0.9905063
# 50 dataset_stamps    DBSCAN    dbscan_1.1 0.18343195          1.0000000
# 51 dataset_wilt      DBSCAN    dbscan_0.3 0.07418655          0.6653696
#    algorithm_f20
# 1  0.2068966
# 2  0.8492063
# 3  0.5600000
# 4  0.0500000
# 5  0.0500000
# 6  0.0500000
# 7  0.0500000
# 8  0.0500000
# 9  0.7065217
# 10 0.2100000
# 11 0.6000000
# 12 0.7000000
# 13 0.7000000
# 14 0.6088083
# 15 0.6088083
# 16 0.6088083
# 17 0.6088083
# 18 0.6088083
# 19 0.3183743
# 20 0.3562005
# 21 0.3562005
# 22 0.3562005
# 23 0.3562005
# 24 0.3562005
# 25 0.5555556
# 26 0.5555556
# 27 0.5555556
# 28 0.5555556
# 29 0.5555556
# 30 0.5522388
# 31 0.5522388
# 32 0.5522388
# 33 0.5522388
# 34 0.5522388
# 35 0.4924242
# 36 0.4924242
# 37 0.4924242
# 38 0.4924242
# 39 0.4924242
# 40 0.5351949
# 41 0.5351949
# 42 0.5351949
# 43 0.5351949
# 44 0.5351949
# 45 0.6431373
# 46 0.6666667
# 47 0.6666667
# 48 0.6081808
# 49 0.5595281
# 50 0.5290102
# 51 0.2565257

# %%
evaluation_algorithms %>%
  filter(algorithm %in% semi_supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f20) %>%
  select(-algorithm_f1, -algorithm_f05)
# Out:
#    dataset           algorithm              variant
# 1  dataset_aloi      oneClassSVM_radial     oneClassSVM_radial
# 2  dataset_iono      oneClassSVM_radial     oneClassSVM_radial
# 3  dataset_kdd       oneClassSVM_radial     oneClassSVM_radial
# 4  dataset_pen       oneClassSVM_polynomial oneClassSVM_polynomial
# 5  dataset_shuttle   oneClassSVM_radial     oneClassSVM_radial
# 6  dataset_waveform  oneClassSVM_radial     oneClassSVM_radial
# 7  dataset_wbc       oneClassSVM_radial     oneClassSVM_radial
# 8  dataset_wdbc      oneClassSVM_radial     oneClassSVM_radial
# 9  dataset_wpbc      oneClassSVM_polynomial oneClassSVM_polynomial
# 10 dataset_ann       oneClassSVM_radial     oneClassSVM_radial
# 11 dataset_arr       oneClassSVM_radial     oneClassSVM_radial
# 12 dataset_cardio    oneClassSVM_radial     oneClassSVM_radial
# 13 dataset_heart     oneClassSVM_radial     oneClassSVM_radial
# 14 dataset_hepatitis oneClassSVM_radial     oneClassSVM_radial
# 15 dataset_ads       oneClassSVM_radial     oneClassSVM_radial
# 16 dataset_blocks    oneClassSVM_radial     oneClassSVM_radial
# 17 dataset_parkinson oneClassSVM_radial     oneClassSVM_radial
# 18 dataset_pima      oneClassSVM_radial     oneClassSVM_radial
# 19 dataset_spam      oneClassSVM_radial     oneClassSVM_radial
# 20 dataset_stamps    oneClassSVM_radial     oneClassSVM_radial
# 21 dataset_wilt      oneClassSVM_linear     oneClassSVM_linear
#    algorithm_precision algorithm_recall algorithm_f20
# 1  0.034984664         0.5776777        0.14081243
# 2  0.518401491         0.9769231        0.83008287
# 3  0.008277033         1.0000000        0.04005889
# 4  0.004029698         1.0000000        0.01982887
# 5  0.025233064         1.0000000        0.11459862
# 6  0.046215005         0.8100000        0.18813779
# 7  0.093453116         1.0000000        0.34012326
# 8  0.052559335         1.0000000        0.21714474
# 9  0.235025995         0.7750000        0.53100322
# 10 0.115936939         0.8091894        0.36849793
# 11 0.163381320         0.8833333        0.46952974
# 12 0.311806104         0.9100465        0.65767828
# 13 0.321856061         0.9250000        0.67282949
# 14 0.238174603         1.0000000        0.60986019
# 15 0.261059873         0.8426426        0.58291977
# 16 0.172214266         0.9960784        0.50903704
# 17 0.355000000         0.9500000        0.71149789
# 18 0.270175800         0.7532051        0.55481998
# 19 0.306859446         0.8875744        0.64387475
# 20 0.164941919         1.0000000        0.49688255
# 21 0.107084703         0.7767692        0.34511471

# %% [markdown]
# # 1.3) Best Algorithm in F0.5

# %%
evaluation_algorithms %>% group_by(dataset) %>% top_n(1, algorithm_f05) %>% select(-algorithm_f1, -algorithm_f20)
# Out:
#    dataset           algorithm      variant        algorithm_precision
# 1  dataset_aloi      randomForest   rf             0.6000766
# 2  dataset_iono      SVM_radial     SVM_radial     0.9294872
# 3  dataset_kdd       randomForest   rf             0.8544737
# 4  dataset_pen       neuralNetwork  mlp            1.0000000
# 5  dataset_shuttle   CART           cart           0.9000000
# 6  dataset_waveform  SVM_radial     SVM_radial     0.6000000
# 7  dataset_wbc       randomForest   rf             0.9000000
# 8  dataset_wdbc      naiveBayes     nb             0.9000000
# 9  dataset_wdbc      neuralNetwork  mlp            0.9000000
# 10 dataset_wdbc      SVM_linear     SVM_linear     0.9000000
# 11 dataset_wdbc      SVM_polynomial SVM_polynomial 0.9000000
# 12 dataset_wpbc      SVM_linear     SVM_linear     0.5200000
# 13 dataset_ann       randomForest   rf             0.9685185
# 14 dataset_arr       randomForest   rf             0.5666667
# 15 dataset_cardio    randomForest   rf             0.9001742
# 16 dataset_heart     naiveBayes     nb             0.6250000
# 17 dataset_hepatitis randomForest   rf             0.6000000
# 18 dataset_ads       randomForest   rf             0.8802553
# 19 dataset_blocks    randomForest   rf             0.8861176
# 20 dataset_parkinson SVM_linear     SVM_linear     0.9500000
# 21 dataset_parkinson SVM_polynomial SVM_polynomial 0.9500000
# 22 dataset_pima      randomForest   rf             0.5307692
# 23 dataset_spam      randomForest   rf             0.8732143
# 24 dataset_stamps    neuralNetwork  mlp            0.8000000
# 25 dataset_wilt      neuralNetwork  mlp            0.8961538
#    algorithm_recall algorithm_f05
# 1  0.5795629        0.5958585
# 2  0.9371795        0.9310155
# 3  0.8500000        0.8535752
# 4  1.0000000        1.0000000
# 5  0.9000000        0.9000000
# 6  0.6000000        0.6000000
# 7  0.9000000        0.9000000
# 8  0.9000000        0.9000000
# 9  0.9000000        0.9000000
# 10 0.9000000        0.9000000
# 11 0.9000000        0.9000000
# 12 0.5550000        0.5266423
# 13 0.9793850        0.9706725
# 14 0.6166667        0.5760073
# 15 0.8979675        0.8997320
# 16 0.6833333        0.6358561
# 17 0.8500000        0.6375000
# 18 0.8805556        0.8803153
# 19 0.8843137        0.8857563
# 20 0.9000000        0.9395604
# 21 0.9000000        0.9395604
# 22 0.5519231        0.5348693
# 23 0.8718254        0.8729362
# 24 1.0000000        0.8333333
# 25 0.9063077        0.8981664

# %%
evaluation_algorithms %>%
  filter(algorithm %in% supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f05) %>%
  select(-algorithm_f1, -algorithm_f20)
# Out:
#    dataset           algorithm      variant        algorithm_precision
# 1  dataset_aloi      randomForest   rf             0.6000766
# 2  dataset_iono      SVM_radial     SVM_radial     0.9294872
# 3  dataset_kdd       randomForest   rf             0.8544737
# 4  dataset_pen       neuralNetwork  mlp            1.0000000
# 5  dataset_shuttle   CART           cart           0.9000000
# 6  dataset_waveform  SVM_radial     SVM_radial     0.6000000
# 7  dataset_wbc       randomForest   rf             0.9000000
# 8  dataset_wdbc      naiveBayes     nb             0.9000000
# 9  dataset_wdbc      neuralNetwork  mlp            0.9000000
# 10 dataset_wdbc      SVM_linear     SVM_linear     0.9000000
# 11 dataset_wdbc      SVM_polynomial SVM_polynomial 0.9000000
# 12 dataset_wpbc      SVM_linear     SVM_linear     0.5200000
# 13 dataset_ann       randomForest   rf             0.9685185
# 14 dataset_arr       randomForest   rf             0.5666667
# 15 dataset_cardio    randomForest   rf             0.9001742
# 16 dataset_heart     naiveBayes     nb             0.6250000
# 17 dataset_hepatitis randomForest   rf             0.6000000
# 18 dataset_ads       randomForest   rf             0.8802553
# 19 dataset_blocks    randomForest   rf             0.8861176
# 20 dataset_parkinson SVM_linear     SVM_linear     0.9500000
# 21 dataset_parkinson SVM_polynomial SVM_polynomial 0.9500000
# 22 dataset_pima      randomForest   rf             0.5307692
# 23 dataset_spam      randomForest   rf             0.8732143
# 24 dataset_stamps    neuralNetwork  mlp            0.8000000
# 25 dataset_wilt      neuralNetwork  mlp            0.8961538
#    algorithm_recall algorithm_f05
# 1  0.5795629        0.5958585
# 2  0.9371795        0.9310155
# 3  0.8500000        0.8535752
# 4  1.0000000        1.0000000
# 5  0.9000000        0.9000000
# 6  0.6000000        0.6000000
# 7  0.9000000        0.9000000
# 8  0.9000000        0.9000000
# 9  0.9000000        0.9000000
# 10 0.9000000        0.9000000
# 11 0.9000000        0.9000000
# 12 0.5550000        0.5266423
# 13 0.9793850        0.9706725
# 14 0.6166667        0.5760073
# 15 0.8979675        0.8997320
# 16 0.6833333        0.6358561
# 17 0.8500000        0.6375000
# 18 0.8805556        0.8803153
# 19 0.8843137        0.8857563
# 20 0.9000000        0.9395604
# 21 0.9000000        0.9395604
# 22 0.5519231        0.5348693
# 23 0.8718254        0.8729362
# 24 1.0000000        0.8333333
# 25 0.9063077        0.8981664

# %%
evaluation_algorithms %>%
  filter(algorithm %in% unsupervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f05) %>%
  select(-algorithm_f1, -algorithm_f20)
# Out:
#    dataset           algorithm variant   algorithm_precision algorithm_recall
# 1  dataset_aloi      LOF       lof_03    0.2068966           0.2068966
# 2  dataset_iono      kmeans    kmeans_25 0.8492063           0.8492063
# 3  dataset_kdd       kmeans    kmeans_08 0.5600000           0.5600000
# 4  dataset_pen       LOF       lof_03    0.0500000           0.0500000
# 5  dataset_pen       LOF       lof_05    0.0500000           0.0500000
# 6  dataset_pen       LOF       lof_08    0.0500000           0.0500000
# 7  dataset_pen       LOF       lof_14    0.0500000           0.0500000
# 8  dataset_pen       LOF       lof_19    0.0500000           0.0500000
# 9  dataset_shuttle   kmeans    kmeans_14 0.3846154           0.3846154
# 10 dataset_shuttle   kmeans    kmeans_19 0.3846154           0.3846154
# 11 dataset_shuttle   kmeans    kmeans_25 0.3846154           0.3846154
# 12 dataset_shuttle   kmeans    kmeans_30 0.3846154           0.3846154
# 13 dataset_waveform  kmeans    kmeans_30 0.2100000           0.2100000
# 14 dataset_wbc       kmeans    kmeans_19 0.6000000           0.6000000
# 15 dataset_wdbc      kmeans    kmeans_30 0.7000000           0.7000000
# 16 dataset_wdbc      LOF       lof_19    0.7000000           0.7000000
# 17 dataset_wpbc      kmeans    kmeans_30 0.2978723           0.2978723
# 18 dataset_ann       LOF       lof_05    0.1666667           0.1666667
# 19 dataset_ann       LOF       lof_19    0.1666667           0.1666667
# 20 dataset_arr       kmeans    kmeans_03 0.3333333           0.3333333
# 21 dataset_arr       LOF       lof_19    0.3333333           0.3333333
# 22 dataset_arr       LOF       lof_25    0.3333333           0.3333333
# 23 dataset_arr       LOF       lof_30    0.3333333           0.3333333
# 24 dataset_cardio    kmeans    kmeans_03 0.3640777           0.3640777
# 25 dataset_heart     kmeans    kmeans_14 0.3513514           0.3513514
# 26 dataset_heart     kmeans    kmeans_30 0.3513514           0.3513514
# 27 dataset_hepatitis kmeans    kmeans_25 0.3076923           0.3076923
# 28 dataset_hepatitis LOF       lof_25    0.3076923           0.3076923
# 29 dataset_hepatitis LOF       lof_30    0.3076923           0.3076923
# 30 dataset_ads       LOF       lof_30    0.3641304           0.3641304
# 31 dataset_blocks    kmeans    kmeans_03 0.6431373           0.6431373
# 32 dataset_parkinson kmeans    kmeans_08 0.6666667           0.6666667
# 33 dataset_parkinson kmeans    kmeans_14 0.6666667           0.6666667
# 34 dataset_pima      kmeans    kmeans_03 0.4000000           0.4000000
# 35 dataset_pima      kmeans    kmeans_19 0.4000000           0.4000000
# 36 dataset_spam      kmeans    kmeans_30 0.3180380           0.3180380
# 37 dataset_stamps    kmeans    kmeans_19 0.2258065           0.2258065
# 38 dataset_stamps    kmeans    kmeans_25 0.2258065           0.2258065
# 39 dataset_wilt      LOF       lof_05    0.1517510           0.1517510
#    algorithm_f05
# 1  0.2068966
# 2  0.8492063
# 3  0.5600000
# 4  0.0500000
# 5  0.0500000
# 6  0.0500000
# 7  0.0500000
# 8  0.0500000
# 9  0.3846154
# 10 0.3846154
# 11 0.3846154
# 12 0.3846154
# 13 0.2100000
# 14 0.6000000
# 15 0.7000000
# 16 0.7000000
# 17 0.2978723
# 18 0.1666667
# 19 0.1666667
# 20 0.3333333
# 21 0.3333333
# 22 0.3333333
# 23 0.3333333
# 24 0.3640777
# 25 0.3513514
# 26 0.3513514
# 27 0.3076923
# 28 0.3076923
# 29 0.3076923
# 30 0.3641304
# 31 0.6431373
# 32 0.6666667
# 33 0.6666667
# 34 0.4000000
# 35 0.4000000
# 36 0.3180380
# 37 0.2258065
# 38 0.2258065
# 39 0.1517510

# %%
evaluation_algorithms %>%
  filter(algorithm %in% semi_supervised_algorithms) %>%
  group_by(dataset) %>%
  top_n(1, algorithm_f05) %>%
  select(-algorithm_f1, -algorithm_f20)
# Out:
#    dataset           algorithm              variant
# 1  dataset_aloi      oneClassSVM_radial     oneClassSVM_radial
# 2  dataset_iono      oneClassSVM_radial     oneClassSVM_radial
# 3  dataset_kdd       oneClassSVM_radial     oneClassSVM_radial
# 4  dataset_pen       oneClassSVM_polynomial oneClassSVM_polynomial
# 5  dataset_shuttle   oneClassSVM_radial     oneClassSVM_radial
# 6  dataset_waveform  oneClassSVM_radial     oneClassSVM_radial
# 7  dataset_wbc       oneClassSVM_radial     oneClassSVM_radial
# 8  dataset_wdbc      oneClassSVM_radial     oneClassSVM_radial
# 9  dataset_wpbc      oneClassSVM_radial     oneClassSVM_radial
# 10 dataset_ann       oneClassSVM_radial     oneClassSVM_radial
# 11 dataset_arr       oneClassSVM_radial     oneClassSVM_radial
# 12 dataset_cardio    oneClassSVM_radial     oneClassSVM_radial
# 13 dataset_heart     oneClassSVM_radial     oneClassSVM_radial
# 14 dataset_hepatitis oneClassSVM_radial     oneClassSVM_radial
# 15 dataset_ads       oneClassSVM_radial     oneClassSVM_radial
# 16 dataset_blocks    oneClassSVM_radial     oneClassSVM_radial
# 17 dataset_parkinson oneClassSVM_radial     oneClassSVM_radial
# 18 dataset_pima      oneClassSVM_radial     oneClassSVM_radial
# 19 dataset_spam      oneClassSVM_radial     oneClassSVM_radial
# 20 dataset_stamps    oneClassSVM_radial     oneClassSVM_radial
# 21 dataset_wilt      oneClassSVM_linear     oneClassSVM_linear
#    algorithm_precision algorithm_recall algorithm_f05
# 1  0.034984664         0.5776777        0.043078611
# 2  0.518401491         0.9769231        0.572105340
# 3  0.008277033         1.0000000        0.010324927
# 4  0.004029698         1.0000000        0.005032053
# 5  0.025233064         1.0000000        0.031343606
# 6  0.046215005         0.8100000        0.056956337
# 7  0.093453116         1.0000000        0.114149488
# 8  0.052559335         1.0000000        0.064847089
# 9  0.253767066         0.5900000        0.286411462
# 10 0.115936939         0.8091894        0.139909767
# 11 0.163381320         0.8833333        0.195200576
# 12 0.311806104         0.9100465        0.359006351
# 13 0.321856061         0.9250000        0.370123709
# 14 0.238174603         1.0000000        0.280987247
# 15 0.261059873         0.8426426        0.302866970
# 16 0.172214266         0.9960784        0.206348805
# 17 0.355000000         0.9500000        0.405836342
# 18 0.270175800         0.7532051        0.309926937
# 19 0.306859446         0.8875744        0.353058723
# 20 0.164941919         1.0000000        0.198012268
# 21 0.107084703         0.7767692        0.129396265

# %% [markdown]
# # 1.4) Do the algorithms have better performance than random guessing, considering the F1 metric?

# %%
calc_better_random <- function()
{
  random_guess <- evaluation_algorithms %>%
    group_by(dataset) %>%
    filter(algorithm == "random") %>%
    select(dataset, random_f1 = algorithm_f1)
  
  number_variants <- evaluation_algorithms %>% .$variant %>% unique %>% length
  
  evaluation_algorithms %>%
    select(-algorithm_precision, -algorithm_recall, -algorithm_f20, -algorithm_f05) %>%
    left_join(random_guess, by="dataset") %>%
    filter(algorithm_f1 > random_f1) %>%
    group_by(dataset) %>%
    summarise(better_than_random = n(), better_than_random_ratio = n()/number_variants)
}

calc_better_random()
# Out:
#    dataset           better_than_random better_than_random_ratio
# 1  dataset_ads       24                 0.75000
# 2  dataset_aloi      30                 0.93750
# 3  dataset_ann       31                 0.96875
# 4  dataset_arr       30                 0.93750
# 5  dataset_blocks    30                 0.93750
# 6  dataset_cardio    29                 0.90625
# 7  dataset_heart     27                 0.84375
# 8  dataset_hepatitis 24                 0.75000
# 9  dataset_iono      29                 0.90625
# 10 dataset_kdd       30                 0.93750
# 11 dataset_parkinson 29                 0.90625
# 12 dataset_pen       20                 0.62500
# 13 dataset_pima      31                 0.96875
# 14 dataset_shuttle   31                 0.96875
# 15 dataset_spam      29                 0.90625
# 16 dataset_stamps    31                 0.96875
# 17 dataset_waveform  31                 0.96875
# 18 dataset_wbc       18                 0.56250
# 19 dataset_wdbc      21                 0.65625
# 20 dataset_wilt      18                 0.56250
# 21 dataset_wpbc      17                 0.53125

# %%
options(repr.plot.width=6, repr.plot.height=3)
calc_better_random() %>% ggplot(aes(better_than_random_ratio)) + geom_histogram(bins = 30)
# Out:
# plot without title

# %%
options(repr.matrix.max.rows=600, repr.matrix.max.cols=200)
calc_worse_random_algorithms <- function()
{
  random_guess <- evaluation_algorithms %>%
    group_by(dataset) %>%
    filter(algorithm == "random") %>%
    select(dataset, random_f1 = algorithm_f1)
  
  evaluation_algorithms %>%
    select(-algorithm_precision, -algorithm_recall, -algorithm_f20, -algorithm_f05) %>%
    left_join(random_guess, by="dataset") %>%
    filter(algorithm_f1 <= random_f1)
}

calc_worse_random_algorithms()
# Out:
#     dataset           algorithm              variant
# 1   dataset_aloi      CART                   cart
# 2   dataset_aloi      random                 random
# 3   dataset_iono      oneClassSVM_polynomial oneClassSVM_polynomial
# 4   dataset_iono      oneClassSVM_sigmoid    oneClassSVM_sigmoid
# 5   dataset_iono      random                 random
# 6   dataset_kdd       naiveBayes             nb
# 7   dataset_kdd       random                 random
# 8   dataset_pen       kmeans                 kmeans_03
# 9   dataset_pen       kmeans                 kmeans_05
# 10  dataset_pen       kmeans                 kmeans_08
# 11  dataset_pen       kmeans                 kmeans_14
# 12  dataset_pen       kmeans                 kmeans_19
# 13  dataset_pen       kmeans                 kmeans_25
# 14  dataset_pen       kmeans                 kmeans_30
# 15  dataset_pen       LOF                    lof_25
# 16  dataset_pen       LOF                    lof_30
# 17  dataset_pen       oneClassSVM_sigmoid    oneClassSVM_sigmoid
# 18  dataset_pen       SVM_sigmoid            SVM_sigmoid
# 19  dataset_pen       random                 random
# 20  dataset_shuttle   random                 random
# 21  dataset_waveform  random                 random
# 22  dataset_wbc       DBSCAN                 dbscan_0.3
# 23  dataset_wbc       DBSCAN                 dbscan_0.5
# 24  dataset_wbc       DBSCAN                 dbscan_0.7
# 25  dataset_wbc       LOF                    lof_03
# 26  dataset_wbc       LOF                    lof_05
# 27  dataset_wbc       LOF                    lof_08
# 28  dataset_wbc       LOF                    lof_14
# 29  dataset_wbc       LOF                    lof_19
# 30  dataset_wbc       LOF                    lof_25
# 31  dataset_wbc       oneClassSVM_linear     oneClassSVM_linear
# 32  dataset_wbc       oneClassSVM_polynomial oneClassSVM_polynomial
# 33  dataset_wbc       oneClassSVM_sigmoid    oneClassSVM_sigmoid
# 34  dataset_wbc       SVM_sigmoid            SVM_sigmoid
# 35  dataset_wbc       random                 random
# 36  dataset_wdbc      DBSCAN                 dbscan_0.3
# 37  dataset_wdbc      DBSCAN                 dbscan_0.5
# 38  dataset_wdbc      DBSCAN                 dbscan_0.7
# 39  dataset_wdbc      DBSCAN                 dbscan_0.9
# 40  dataset_wdbc      DBSCAN                 dbscan_1.1
# 41  dataset_wdbc      LOF                    lof_03
# 42  dataset_wdbc      LOF                    lof_05
# 43  dataset_wdbc      oneClassSVM_linear     oneClassSVM_linear
# 44  dataset_wdbc      oneClassSVM_polynomial oneClassSVM_polynomial
# 45  dataset_wdbc      oneClassSVM_sigmoid    oneClassSVM_sigmoid
# 46  dataset_wdbc      random                 random
# 47  dataset_wpbc      kmeans                 kmeans_03
# 48  dataset_wpbc      kmeans                 kmeans_05
# 49  dataset_wpbc      kmeans                 kmeans_08
# 50  dataset_wpbc      kmeans                 kmeans_14
# 51  dataset_wpbc      kmeans                 kmeans_19
# 52  dataset_wpbc      kmeans                 kmeans_25
# 53  dataset_wpbc      LOF                    lof_03
# 54  dataset_wpbc      LOF                    lof_05
# 55  dataset_wpbc      LOF                    lof_08
# 56  dataset_wpbc      LOF                    lof_14
# 57  dataset_wpbc      LOF                    lof_19
# 58  dataset_wpbc      LOF                    lof_25
# 59  dataset_wpbc      LOF                    lof_30
# 60  dataset_wpbc      oneClassSVM_sigmoid    oneClassSVM_sigmoid
# 61  dataset_wpbc      random                 random
# 62  dataset_ann       random                 random
# 63  dataset_arr       naiveBayes             nb
# 64  dataset_arr       random                 random
# 65  dataset_cardio    oneClassSVM_linear     oneClassSVM_linear
# 66  dataset_cardio    oneClassSVM_polynomial oneClassSVM_polynomial
# 67  dataset_cardio    random                 random
# 68  dataset_heart     LOF                    lof_05
# 69  dataset_heart     LOF                    lof_08
# 70  dataset_heart     LOF                    lof_25
# 71  dataset_heart     LOF                    lof_30
# 72  dataset_heart     random                 random
# 73  dataset_hepatitis CART                   cart
# 74  dataset_hepatitis kmeans                 kmeans_03
# 75  dataset_hepatitis kmeans                 kmeans_08
# 76  dataset_hepatitis kmeans                 kmeans_14
# 77  dataset_hepatitis kmeans                 kmeans_30
# 78  dataset_hepatitis LOF                    lof_05
# 79  dataset_hepatitis LOF                    lof_19
# 80  dataset_hepatitis random                 random
# 81  dataset_ads       kmeans                 kmeans_14
# 82  dataset_ads       kmeans                 kmeans_25
# 83  dataset_ads       kmeans                 kmeans_30
# 84  dataset_ads       LOF                    lof_03
# 85  dataset_ads       LOF                    lof_05
# 86  dataset_ads       naiveBayes             nb
# 87  dataset_ads       oneClassSVM_linear     oneClassSVM_linear
# 88  dataset_ads       random                 random
# 89  dataset_blocks    oneClassSVM_polynomial oneClassSVM_polynomial
# 90  dataset_blocks    random                 random
# 91  dataset_parkinson kmeans                 kmeans_25
# 92  dataset_parkinson kmeans                 kmeans_30
# 93  dataset_parkinson random                 random
# 94  dataset_pima      random                 random
# 95  dataset_spam      naiveBayes             nb
# 96  dataset_spam      oneClassSVM_polynomial oneClassSVM_polynomial
# 97  dataset_spam      random                 random
# 98  dataset_stamps    random                 random
# 99  dataset_wilt      DBSCAN                 dbscan_0.5
# 100 dataset_wilt      DBSCAN                 dbscan_0.7
# 101 dataset_wilt      DBSCAN                 dbscan_0.9
# 102 dataset_wilt      DBSCAN                 dbscan_1.1
# 103 dataset_wilt      kmeans                 kmeans_03
# 104 dataset_wilt      kmeans                 kmeans_05
# 105 dataset_wilt      kmeans                 kmeans_08
# 106 dataset_wilt      kmeans                 kmeans_14
# 107 dataset_wilt      kmeans                 kmeans_19
# 108 dataset_wilt      kmeans                 kmeans_25
# 109 dataset_wilt      kmeans                 kmeans_30
# 110 dataset_wilt      LOF                    lof_30
# 111 dataset_wilt      SVM_sigmoid            SVM_sigmoid
# 112 dataset_wilt      random                 random
#     algorithm_f1 random_f1
# 1   0.000000000  0.03743316
# 2   0.037433155  0.03743316
# 3   0.215912602  0.36434109
# 4   0.217882209  0.36434109
# 5   0.364341085  0.36434109
# 6   0.000000000  0.00000000
# 7   0.000000000  0.00000000
# 8   0.000000000  0.00000000
# 9   0.000000000  0.00000000
# 10  0.000000000  0.00000000
# 11  0.000000000  0.00000000
# 12  0.000000000  0.00000000
# 13  0.000000000  0.00000000
# 14  0.000000000  0.00000000
# 15  0.000000000  0.00000000
# 16  0.000000000  0.00000000
# 17  0.000000000  0.00000000
# 18  0.000000000  0.00000000
# 19  0.000000000  0.00000000
# 20  0.000000000  0.00000000
# 21  0.020725389  0.02072539
# 22  0.085836910  0.16666667
# 23  0.085836910  0.16666667
# 24  0.085836910  0.16666667
# 25  0.000000000  0.16666667
# 26  0.000000000  0.16666667
# 27  0.000000000  0.16666667
# 28  0.000000000  0.16666667
# 29  0.000000000  0.16666667
# 30  0.100000000  0.16666667
# 31  0.011764706  0.16666667
# 32  0.100012096  0.16666667
# 33  0.157792208  0.16666667
# 34  0.100000000  0.16666667
# 35  0.166666667  0.16666667
# 36  0.053050398  0.09523810
# 37  0.053050398  0.09523810
# 38  0.053050398  0.09523810
# 39  0.053050398  0.09523810
# 40  0.053050398  0.09523810
# 41  0.000000000  0.09523810
# 42  0.000000000  0.09523810
# 43  0.000000000  0.09523810
# 44  0.000000000  0.09523810
# 45  0.093839463  0.09523810
# 46  0.095238095  0.09523810
# 47  0.170212766  0.27722772
# 48  0.170212766  0.27722772
# 49  0.148936170  0.27722772
# 50  0.148936170  0.27722772
# 51  0.191489362  0.27722772
# 52  0.234042553  0.27722772
# 53  0.148936170  0.27722772
# 54  0.127659574  0.27722772
# 55  0.170212766  0.27722772
# 56  0.170212766  0.27722772
# 57  0.191489362  0.27722772
# 58  0.170212766  0.27722772
# 59  0.170212766  0.27722772
# 60  0.258675184  0.27722772
# 61  0.277227723  0.27722772
# 62  0.062559242  0.06255924
# 63  0.000000000  0.10169492
# 64  0.101694915  0.10169492
# 65  0.148853901  0.22884386
# 66  0.129108094  0.22884386
# 67  0.228843862  0.22884386
# 68  0.162162162  0.16867470
# 69  0.162162162  0.16867470
# 70  0.162162162  0.16867470
# 71  0.162162162  0.16867470
# 72  0.168674699  0.16867470
# 73  0.166666667  0.16666667
# 74  0.076923077  0.16666667
# 75  0.153846154  0.16666667
# 76  0.153846154  0.16666667
# 77  0.153846154  0.16666667
# 78  0.153846154  0.16666667
# 79  0.153846154  0.16666667
# 80  0.166666667  0.16666667
# 81  0.206521739  0.21192053
# 82  0.144021739  0.21192053
# 83  0.198369565  0.21192053
# 84  0.176630435  0.21192053
# 85  0.195652174  0.21192053
# 86  0.000000000  0.21192053
# 87  0.209440772  0.21192053
# 88  0.211920530  0.21192053
# 89  0.040893257  0.10967099
# 90  0.109670987  0.10967099
# 91  0.166666667  0.28571429
# 92  0.166666667  0.28571429
# 93  0.285714286  0.28571429
# 94  0.212927757  0.21292776
# 95  0.000000000  0.22292490
# 96  0.110897047  0.22292490
# 97  0.222924901  0.22292490
# 98  0.093750000  0.09375000
# 99  0.024229075  0.03976143
# 100 0.003663004  0.03976143
# 101 0.000000000  0.03976143
# 102 0.000000000  0.03976143
# 103 0.003891051  0.03976143
# 104 0.003891051  0.03976143
# 105 0.003891051  0.03976143
# 106 0.003891051  0.03976143
# 107 0.003891051  0.03976143
# 108 0.003891051  0.03976143
# 109 0.003891051  0.03976143
# 110 0.038910506  0.03976143
# 111 0.038612368  0.03976143
# 112 0.039761431  0.03976143

# %%
options(repr.plot.width=12, repr.plot.height=3)

calc_worse_random_algorithms() %>% distinct(dataset, algorithm) %>% group_by(algorithm) %>% summarise(count = n())

calc_worse_random_algorithms() %>% filter(algorithm != "random") %>% distinct(dataset, algorithm) %>% group_by(algorithm) %>% summarise(count = n()) %>%
  ggplot(aes(algorithm, count)) + geom_bar(stat = "identity")
# Out:
#    algorithm              count
# 1  CART                    2
# 2  DBSCAN                  3
# 3  kmeans                  6
# 4  LOF                     8
# 5  naiveBayes              4
# 6  oneClassSVM_linear      4
# 7  oneClassSVM_polynomial  6
# 8  oneClassSVM_sigmoid     5
# 9  random                 21
# 10 SVM_sigmoid             3
# plot without title

# %% [markdown]
# # 2) Diversity Performance Study

# %%
change_numeric_to_binary <- function(dataset, columnName)
{
  if(columnName %in% colnames(dataset))
  {
    outlierRatio <- prop.table(table(dataset$outlier))["yes"]
    dataset[[columnName]] <- ifelse(dataset[[columnName]] > quantile(dataset[[columnName]], prob = 1 - outlierRatio), "yes", "no")
    dataset[[columnName]] <- dataset[[columnName]] %>% factor(levels = c("yes", "no"))
  }
  
  return(dataset)
}

normalize_factors <- function(dataset)
{
  dataset$dbscan_0.3 <- factor(dataset$dbscan_0.3, levels = c("yes", "no"))
  dataset$dbscan_0.5 <- factor(dataset$dbscan_0.5, levels = c("yes", "no"))
  dataset$dbscan_0.7 <- factor(dataset$dbscan_0.7, levels = c("yes", "no"))
  dataset$dbscan_0.9 <- factor(dataset$dbscan_0.9, levels = c("yes", "no"))
  dataset$dbscan_1.1 <- factor(dataset$dbscan_1.1, levels = c("yes", "no"))
  dataset$oneClassSVM_linear <- factor(dataset$oneClassSVM_linear, levels = c("yes", "no"))
  dataset$oneClassSVM_polynomial <- factor(dataset$oneClassSVM_polynomial, levels = c("yes", "no"))
  dataset$oneClassSVM_radial <- factor(dataset$oneClassSVM_radial, levels = c("yes", "no"))
  dataset$oneClassSVM_sigmoid <- factor(dataset$oneClassSVM_sigmoid, levels = c("yes", "no"))
  dataset$outlier <- factor(dataset$outlier, levels = c("yes", "no"))
  return(dataset)
}

# %%
datasets_df <- NULL

for(dname in datasets)
{
  dataset <- read.csv(paste0("results_algorithms_joined/", dname, ".csv"))
  dataset <- normalize_factors(dataset)

  for(colname in colnames(dataset))
  {
    if (colname %in% c("cart", "kmeans_03","kmeans_05","kmeans_08","kmeans_14","kmeans_19","kmeans_25","kmeans_30","lof_03","lof_05","lof_08","lof_14","lof_19","lof_25","lof_30","nb","mlp","rf","SVM_linear","SVM_polynomial","SVM_radial","SVM_sigmoid"))
      dataset <- change_numeric_to_binary(dataset, colname)
  }
    
  dataset <- dataset %>%
    #select(outlier:SVM_sigmoid) %>%
    select(outlier, cart, rf, nb, mlp, SVM_linear, SVM_polynomial, SVM_radial, SVM_sigmoid,
          oneClassSVM_linear, oneClassSVM_polynomial, oneClassSVM_radial, oneClassSVM_sigmoid,
          lof_03, lof_05, lof_08, lof_14, lof_19, lof_25, lof_30,
          dbscan_0.3, dbscan_0.5, dbscan_0.7, dbscan_0.9, dbscan_1.1,
          kmeans_03, kmeans_05, kmeans_08, kmeans_14, kmeans_19, kmeans_25, kmeans_30) %>%
    mutate(dataset = rep(dname, nrow(dataset))) %>%
    select(dataset, everything())
  
    if (is.null(datasets_df))
      datasets_df <- dataset
    else
      datasets_df <- bind_rows(datasets_df, dataset)
}

# %%
options(repr.plot.width=12, repr.plot.height=12)

for(dname in unique(datasets_df$dataset))
{
  dataset_data <- datasets_df %>% filter(dataset == dname) %>% select(-dataset, -outlier)
  
  for(colname in colnames(dataset_data))
    dataset_data[[colname]] <- ifelse(dataset_data[[colname]] == "yes", 1, 0)
   
  #a <- simil(t(dataset_data %>% select(-)), method = "simple matching", diag = TRUE, upper = TRUE) %>%
  #  as.matrix()
  a <- simil(t(dataset_data), method = "simple matching", diag = TRUE, upper = TRUE) %>%
    as.matrix() %>% stats::as.dist(diag = TRUE, upper = TRUE) %>% tidy(diag = TRUE, upper = TRUE) %>%
    mutate(distance = ifelse(item1 == item2, NA, distance))
    
  (ggplot(a, aes(item1, item2)) +
    coord_equal() +
    scale_x_discrete(position = "top") +
    scale_y_discrete(limits = rev(levels(a$item2))) +
    geom_tile(aes(fill = distance), colour = "white") +
    scale_fill_gradient(low = "white", high = "blue", limits = c(0, 1)) +
    #scale_x_discrete(limits = rev(levels(a$item1))) +
    #scale_y_discrete(limits = rev(levels(a$item2))) +
    theme(axis.text.x = element_text(angle = 45, hjust = 0))) %>% print
}
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=12)

diversity <- sapply(unique(datasets_df$dataset), simplify = "array", function(dname)
{
  dataset_data <- datasets_df %>% filter(dataset == dname) %>% select(-dataset, -outlier)
  
  for(colname in colnames(dataset_data))
    dataset_data[[colname]] <- ifelse(dataset_data[[colname]] == "yes", 1, 0)
   
  similarity <- simil(t(dataset_data), method = "simple matching", diag = TRUE, upper = TRUE) %>%
    as.matrix()
})

# %%
diversity_mean <- apply(diversity, c(1,2), mean)

# %%
diversity_mean <- diversity_mean %>% stats::as.dist(diag = TRUE, upper = TRUE) %>% tidy(diag = TRUE, upper = TRUE) %>%
  mutate(distance = ifelse(item1 == item2, NA, distance))

# %%
ggplot(diversity_mean, aes(item1, item2)) +
    coord_equal() +
    scale_x_discrete(position = "top") +
    scale_y_discrete(limits = rev(levels(a$item2))) +
    geom_tile(aes(fill = distance), colour = "white") +
    scale_fill_gradient(low = "white", high = "blue", limits = c(0, 1)) +
    #scale_x_discrete(limits = rev(levels(a$item1))) +
    #scale_y_discrete(limits = rev(levels(a$item2))) +
    theme(axis.text.x = element_text(angle = 45, hjust = 0))
# Out:
# plot without title

# %%
diversity_sd <- apply(diversity, c(1,2), sd)
diversity_sd
# Out:
#                        cart       rf         nb         mlp        SVM_linear
# cart                           NA 0.05778778 0.07048602 0.07633419 0.07130935
# rf                     0.05778778         NA 0.05845974 0.05694066 0.06312864
# nb                     0.07048602 0.05845974         NA 0.06776657 0.07031796
# mlp                    0.07633419 0.05694066 0.06776657         NA 0.04593343
# SVM_linear             0.07130935 0.06312864 0.07031796 0.04593343         NA
# SVM_polynomial         0.08294326 0.05107512 0.06464042 0.06171223 0.06461613
# SVM_radial             0.07154375 0.04292926 0.05423315 0.04596711 0.05193560
# SVM_sigmoid            0.08186934 0.07087076 0.07192691 0.07249687 0.05627883
# oneClassSVM_linear     0.12711755 0.12850305 0.14098770 0.13016750 0.13148073
# oneClassSVM_polynomial 0.10395055 0.10613620 0.11235863 0.09386211 0.09224078
# oneClassSVM_radial     0.04907892 0.04955776 0.06944153 0.04343716 0.04154763
# oneClassSVM_sigmoid    0.05117282 0.05894433 0.06903991 0.04965095 0.04770930
# lof_03                 0.12131618 0.12161881 0.11664785 0.11745598 0.12209956
# lof_05                 0.12375531 0.11901487 0.11649509 0.11747774 0.12333816
# lof_08                 0.12103809 0.11490250 0.11533538 0.11611314 0.11918602
# lof_14                 0.12114542 0.11360303 0.11200981 0.11922208 0.12032783
# lof_19                 0.11898565 0.11173256 0.11143483 0.11743328 0.11846778
# lof_25                 0.11719038 0.10699979 0.10623616 0.11318500 0.11496745
# lof_30                 0.11685443 0.10793772 0.10714190 0.11366620 0.11637294
# dbscan_0.3             0.22108749 0.21898800 0.23321332 0.21845605 0.21931056
# dbscan_0.5             0.29713156 0.29412075 0.31262134 0.29393873 0.29579689
# dbscan_0.7             0.31937130 0.31524534 0.33679045 0.31473359 0.31673438
# dbscan_0.9             0.32257175 0.31730256 0.34496376 0.31709772 0.31924928
# dbscan_1.1             0.33941545 0.33314945 0.36281637 0.33312464 0.33491430
# kmeans_03              0.11112015 0.09942410 0.09503908 0.11064706 0.11481502
# kmeans_05              0.11401817 0.10558602 0.10426731 0.11488256 0.11766817
# kmeans_08              0.11489530 0.10712695 0.10516964 0.11196905 0.11912049
# kmeans_14              0.11186139 0.10713658 0.10531998 0.11215048 0.11473547
# kmeans_19              0.11263388 0.10408197 0.10365582 0.11095625 0.11242036
# kmeans_25              0.11319924 0.10550195 0.09921692 0.11479266 0.11614359
# kmeans_30              0.11224668 0.10722250 0.10057175 0.11515388 0.11752908
#                        SVM_polynomial SVM_radial SVM_sigmoid oneClassSVM_linear
# cart                   0.08294326     0.07154375 0.08186934  0.12711755
# rf                     0.05107512     0.04292926 0.07087076  0.12850305
# nb                     0.06464042     0.05423315 0.07192691  0.14098770
# mlp                    0.06171223     0.04596711 0.07249687  0.13016750
# SVM_linear             0.06461613     0.05193560 0.05627883  0.13148073
# SVM_polynomial                 NA     0.04404324 0.07874941  0.13348593
# SVM_radial             0.04404324             NA 0.07058804  0.12933092
# SVM_sigmoid            0.07874941     0.07058804         NA  0.13355805
# oneClassSVM_linear     0.13348593     0.12933092 0.13355805          NA
# oneClassSVM_polynomial 0.10116510     0.10422349 0.10327827  0.05340298
# oneClassSVM_radial     0.05265765     0.05193670 0.04581362  0.08124807
# oneClassSVM_sigmoid    0.06655235     0.06225346 0.06276453  0.03080486
# lof_03                 0.11792572     0.11815697 0.12743177  0.11856073
# lof_05                 0.11566295     0.12060574 0.12418734  0.11725333
# lof_08                 0.11136000     0.11813211 0.11922601  0.11846405
# lof_14                 0.10657984     0.11784626 0.11516382  0.11927179
# lof_19                 0.10320038     0.11546669 0.11375755  0.12149555
# lof_25                 0.10052580     0.11304798 0.11114978  0.12174146
# lof_30                 0.10063180     0.11373824 0.11311624  0.12262339
# dbscan_0.3             0.21728986     0.21910657 0.21949009  0.11450330
# dbscan_0.5             0.29411458     0.29515352 0.29559355  0.11697406
# dbscan_0.7             0.31522054     0.31642526 0.31429161  0.11647583
# dbscan_0.9             0.31804307     0.31898227 0.31633276  0.12384364
# dbscan_1.1             0.33388226     0.33498097 0.33199667  0.13723678
# kmeans_03              0.09496506     0.10662849 0.11046875  0.13141195
# kmeans_05              0.09719482     0.11252588 0.11412537  0.13143433
# kmeans_08              0.09676466     0.11179295 0.11073355  0.13404460
# kmeans_14              0.10343569     0.11378842 0.10804240  0.13454492
# kmeans_19              0.10178734     0.10735267 0.11033830  0.13540249
# kmeans_25              0.10154684     0.11033131 0.11048378  0.13409954
# kmeans_30              0.10536238     0.11061255 0.11269864  0.13583248
#                        oneClassSVM_polynomial oneClassSVM_radial
# cart                   0.10395055             0.04907892
# rf                     0.10613620             0.04955776
# nb                     0.11235863             0.06944153
# mlp                    0.09386211             0.04343716
# SVM_linear             0.09224078             0.04154763
# SVM_polynomial         0.10116510             0.05265765
# SVM_radial             0.10422349             0.05193670
# SVM_sigmoid            0.10327827             0.04581362
# oneClassSVM_linear     0.05340298             0.08124807
# oneClassSVM_polynomial         NA             0.13777630
# oneClassSVM_radial     0.13777630                     NA
# oneClassSVM_sigmoid    0.09575102             0.08432024
# lof_03                 0.10294059             0.06561627
# lof_05                 0.10172753             0.06751062
# lof_08                 0.10138546             0.05911439
# lof_14                 0.10201696             0.05688378
# lof_19                 0.10869446             0.05680946
# lof_25                 0.10713807             0.05928093
# lof_30                 0.10648441             0.06027214
# dbscan_0.3             0.17889876             0.08965885
# dbscan_0.5             0.18557981             0.07659139
# dbscan_0.7             0.19007514             0.09567787
# dbscan_0.9             0.18671022             0.09889701
# dbscan_1.1             0.18617055             0.10638326
# kmeans_03              0.10044359             0.06209789
# kmeans_05              0.09750255             0.06208124
# kmeans_08              0.09785065             0.06147629
# kmeans_14              0.09725508             0.06140421
# kmeans_19              0.09461863             0.05937207
# kmeans_25              0.09951355             0.06289947
# kmeans_30              0.10031077             0.05597573
#                        oneClassSVM_sigmoid lof_03     lof_05     lof_08
# cart                   0.05117282          0.12131618 0.12375531 0.12103809
# rf                     0.05894433          0.12161881 0.11901487 0.11490250
# nb                     0.06903991          0.11664785 0.11649509 0.11533538
# mlp                    0.04965095          0.11745598 0.11747774 0.11611314
# SVM_linear             0.04770930          0.12209956 0.12333816 0.11918602
# SVM_polynomial         0.06655235          0.11792572 0.11566295 0.11136000
# SVM_radial             0.06225346          0.11815697 0.12060574 0.11813211
# SVM_sigmoid            0.06276453          0.12743177 0.12418734 0.11922601
# oneClassSVM_linear     0.03080486          0.11856073 0.11725333 0.11846405
# oneClassSVM_polynomial 0.09575102          0.10294059 0.10172753 0.10138546
# oneClassSVM_radial     0.08432024          0.06561627 0.06751062 0.05911439
# oneClassSVM_sigmoid            NA          0.04566418 0.04179565 0.04031133
# lof_03                 0.04566418                  NA 0.04528823 0.06584349
# lof_05                 0.04179565          0.04528823         NA 0.03804068
# lof_08                 0.04031133          0.06584349 0.03804068         NA
# lof_14                 0.04755067          0.08660268 0.06689827 0.04257167
# lof_19                 0.05090441          0.09312869 0.08081547 0.05736094
# lof_25                 0.06450418          0.10045407 0.09017987 0.07231630
# lof_30                 0.06054626          0.10131109 0.09107597 0.07962156
# dbscan_0.3             0.07875925          0.21071200 0.21297979 0.21563149
# dbscan_0.5             0.07761474          0.29054110 0.29369757 0.29562517
# dbscan_0.7             0.07652708          0.31264014 0.31524848 0.31666980
# dbscan_0.9             0.07988879          0.31551104 0.31750028 0.31894712
# dbscan_1.1             0.07977434          0.33198293 0.33365454 0.33547418
# kmeans_03              0.05436686          0.10468050 0.09922341 0.08775655
# kmeans_05              0.05679788          0.09828597 0.09371122 0.08219559
# kmeans_08              0.05311108          0.09513331 0.08596020 0.07663560
# kmeans_14              0.05928902          0.09371590 0.08780507 0.08248299
# kmeans_19              0.05622331          0.10286804 0.09930036 0.08983964
# kmeans_25              0.06070430          0.10984515 0.11339940 0.10434919
# kmeans_30              0.05482794          0.11038684 0.10990153 0.09813377
#                        lof_14     lof_19     lof_25     lof_30     dbscan_0.3
# cart                   0.12114542 0.11898565 0.11719038 0.11685443 0.22108749
# rf                     0.11360303 0.11173256 0.10699979 0.10793772 0.21898800
# nb                     0.11200981 0.11143483 0.10623616 0.10714190 0.23321332
# mlp                    0.11922208 0.11743328 0.11318500 0.11366620 0.21845605
# SVM_linear             0.12032783 0.11846778 0.11496745 0.11637294 0.21931056
# SVM_polynomial         0.10657984 0.10320038 0.10052580 0.10063180 0.21728986
# SVM_radial             0.11784626 0.11546669 0.11304798 0.11373824 0.21910657
# SVM_sigmoid            0.11516382 0.11375755 0.11114978 0.11311624 0.21949009
# oneClassSVM_linear     0.11927179 0.12149555 0.12174146 0.12262339 0.11450330
# oneClassSVM_polynomial 0.10201696 0.10869446 0.10713807 0.10648441 0.17889876
# oneClassSVM_radial     0.05688378 0.05680946 0.05928093 0.06027214 0.08965885
# oneClassSVM_sigmoid    0.04755067 0.05090441 0.06450418 0.06054626 0.07875925
# lof_03                 0.08660268 0.09312869 0.10045407 0.10131109 0.21071200
# lof_05                 0.06689827 0.08081547 0.09017987 0.09107597 0.21297979
# lof_08                 0.04257167 0.05736094 0.07231630 0.07962156 0.21563149
# lof_14                         NA 0.02442991 0.04440757 0.05490685 0.21764444
# lof_19                 0.02442991         NA 0.03285820 0.04428244 0.21850087
# lof_25                 0.04440757 0.03285820         NA 0.01348572 0.21921434
# lof_30                 0.05490685 0.04428244 0.01348572         NA 0.21957203
# dbscan_0.3             0.21764444 0.21850087 0.21921434 0.21957203         NA
# dbscan_0.5             0.29896251 0.30038904 0.30118747 0.30202559 0.11121051
# dbscan_0.7             0.31868258 0.32015243 0.32068706 0.32123773 0.15992448
# dbscan_0.9             0.32119823 0.32208322 0.32232635 0.32266861 0.22111785
# dbscan_1.1             0.33741263 0.33820227 0.33844297 0.33873153 0.26363317
# kmeans_03              0.07673720 0.07270394 0.06463005 0.06403077 0.22167288
# kmeans_05              0.06907324 0.06383983 0.05986032 0.06068864 0.22167288
# kmeans_08              0.06727843 0.06471361 0.06592782 0.06653875 0.22167288
# kmeans_14              0.07330520 0.07117625 0.06139373 0.05952789 0.22167288
# kmeans_19              0.07587798 0.07418936 0.06429796 0.06425995 0.22168050
# kmeans_25              0.08198063 0.07997447 0.07025565 0.06996846 0.22167288
# kmeans_30              0.08131624 0.08438829 0.07742590 0.07891798 0.22188584
#                        dbscan_0.5 dbscan_0.7 dbscan_0.9 dbscan_1.1 kmeans_03
# cart                   0.29713156 0.31937130 0.32257175 0.33941545 0.11112015
# rf                     0.29412075 0.31524534 0.31730256 0.33314945 0.09942410
# nb                     0.31262134 0.33679045 0.34496376 0.36281637 0.09503908
# mlp                    0.29393873 0.31473359 0.31709772 0.33312464 0.11064706
# SVM_linear             0.29579689 0.31673438 0.31924928 0.33491430 0.11481502
# SVM_polynomial         0.29411458 0.31522054 0.31804307 0.33388226 0.09496506
# SVM_radial             0.29515352 0.31642526 0.31898227 0.33498097 0.10662849
# SVM_sigmoid            0.29559355 0.31429161 0.31633276 0.33199667 0.11046875
# oneClassSVM_linear     0.11697406 0.11647583 0.12384364 0.13723678 0.13141195
# oneClassSVM_polynomial 0.18557981 0.19007514 0.18671022 0.18617055 0.10044359
# oneClassSVM_radial     0.07659139 0.09567787 0.09889701 0.10638326 0.06209789
# oneClassSVM_sigmoid    0.07761474 0.07652708 0.07988879 0.07977434 0.05436686
# lof_03                 0.29054110 0.31264014 0.31551104 0.33198293 0.10468050
# lof_05                 0.29369757 0.31524848 0.31750028 0.33365454 0.09922341
# lof_08                 0.29562517 0.31666980 0.31894712 0.33547418 0.08775655
# lof_14                 0.29896251 0.31868258 0.32119823 0.33741263 0.07673720
# lof_19                 0.30038904 0.32015243 0.32208322 0.33820227 0.07270394
# lof_25                 0.30118747 0.32068706 0.32232635 0.33844297 0.06463005
# lof_30                 0.30202559 0.32123773 0.32266861 0.33873153 0.06403077
# dbscan_0.3             0.11121051 0.15992448 0.22111785 0.26363317 0.22167288
# dbscan_0.5                     NA 0.06931631 0.17469965 0.23288346 0.30600913
# dbscan_0.7             0.06931631         NA 0.13553983 0.19555838 0.32496217
# dbscan_0.9             0.17469965 0.13553983         NA 0.08299112 0.32752500
# dbscan_1.1             0.23288346 0.19555838 0.08299112         NA 0.34250300
# kmeans_03              0.30600913 0.32496217 0.32752500 0.34250300         NA
# kmeans_05              0.30603578 0.32582888 0.32821926 0.34300007 0.04400781
# kmeans_08              0.30628485 0.32581683 0.32833145 0.34282111 0.05074001
# kmeans_14              0.30771480 0.32761608 0.32964955 0.34341405 0.05990688
# kmeans_19              0.30821540 0.32827653 0.32932755 0.34259497 0.06676763
# kmeans_25              0.30709450 0.32741587 0.32884484 0.34265904 0.07283920
# kmeans_30              0.30944811 0.32827417 0.32875229 0.34296754 0.08090817
#                        kmeans_05  kmeans_08  kmeans_14  kmeans_19  kmeans_25
# cart                   0.11401817 0.11489530 0.11186139 0.11263388 0.11319924
# rf                     0.10558602 0.10712695 0.10713658 0.10408197 0.10550195
# nb                     0.10426731 0.10516964 0.10531998 0.10365582 0.09921692
# mlp                    0.11488256 0.11196905 0.11215048 0.11095625 0.11479266
# SVM_linear             0.11766817 0.11912049 0.11473547 0.11242036 0.11614359
# SVM_polynomial         0.09719482 0.09676466 0.10343569 0.10178734 0.10154684
# SVM_radial             0.11252588 0.11179295 0.11378842 0.10735267 0.11033131
# SVM_sigmoid            0.11412537 0.11073355 0.10804240 0.11033830 0.11048378
# oneClassSVM_linear     0.13143433 0.13404460 0.13454492 0.13540249 0.13409954
# oneClassSVM_polynomial 0.09750255 0.09785065 0.09725508 0.09461863 0.09951355
# oneClassSVM_radial     0.06208124 0.06147629 0.06140421 0.05937207 0.06289947
# oneClassSVM_sigmoid    0.05679788 0.05311108 0.05928902 0.05622331 0.06070430
# lof_03                 0.09828597 0.09513331 0.09371590 0.10286804 0.10984515
# lof_05                 0.09371122 0.08596020 0.08780507 0.09930036 0.11339940
# lof_08                 0.08219559 0.07663560 0.08248299 0.08983964 0.10434919
# lof_14                 0.06907324 0.06727843 0.07330520 0.07587798 0.08198063
# lof_19                 0.06383983 0.06471361 0.07117625 0.07418936 0.07997447
# lof_25                 0.05986032 0.06592782 0.06139373 0.06429796 0.07025565
# lof_30                 0.06068864 0.06653875 0.05952789 0.06425995 0.06996846
# dbscan_0.3             0.22167288 0.22167288 0.22167288 0.22168050 0.22167288
# dbscan_0.5             0.30603578 0.30628485 0.30771480 0.30821540 0.30709450
# dbscan_0.7             0.32582888 0.32581683 0.32761608 0.32827653 0.32741587
# dbscan_0.9             0.32821926 0.32833145 0.32964955 0.32932755 0.32884484
# dbscan_1.1             0.34300007 0.34282111 0.34341405 0.34259497 0.34265904
# kmeans_03              0.04400781 0.05074001 0.05990688 0.06676763 0.07283920
# kmeans_05                      NA 0.04680030 0.05833635 0.07234901 0.08220361
# kmeans_08              0.04680030         NA 0.05099997 0.06797819 0.08736625
# kmeans_14              0.05833635 0.05099997         NA 0.05002500 0.07191356
# kmeans_19              0.07234901 0.06797819 0.05002500         NA 0.05816519
# kmeans_25              0.08220361 0.08736625 0.07191356 0.05816519         NA
# kmeans_30              0.08174062 0.08359251 0.08727903 0.05938486 0.05810819
#                        kmeans_30
# cart                   0.11224668
# rf                     0.10722250
# nb                     0.10057175
# mlp                    0.11515388
# SVM_linear             0.11752908
# SVM_polynomial         0.10536238
# SVM_radial             0.11061255
# SVM_sigmoid            0.11269864
# oneClassSVM_linear     0.13583248
# oneClassSVM_polynomial 0.10031077
# oneClassSVM_radial     0.05597573
# oneClassSVM_sigmoid    0.05482794
# lof_03                 0.11038684
# lof_05                 0.10990153
# lof_08                 0.09813377
# lof_14                 0.08131624
# lof_19                 0.08438829
# lof_25                 0.07742590
# lof_30                 0.07891798
# dbscan_0.3             0.22188584
# dbscan_0.5             0.30944811
# dbscan_0.7             0.32827417
# dbscan_0.9             0.32875229
# dbscan_1.1             0.34296754
# kmeans_03              0.08090817
# kmeans_05              0.08174062
# kmeans_08              0.08359251
# kmeans_14              0.08727903
# kmeans_19              0.05938486
# kmeans_25              0.05810819
# kmeans_30                      NA

# %%
diversity_sd <- diversity_sd %>% stats::as.dist(diag = TRUE, upper = TRUE) %>% tidy(diag = TRUE, upper = TRUE) %>%
  mutate(distance = ifelse(item1 == item2, NA, distance))

# %%
ggplot(diversity_sd, aes(item1, item2)) +
    coord_equal() +
    scale_x_discrete(position = "top") +
    scale_y_discrete(limits = rev(levels(a$item2))) +
    geom_tile(aes(fill = distance), colour = "white") +
    scale_fill_gradient(low = "white", high = "blue") +
    #scale_x_discrete(limits = rev(levels(a$item1))) +
    #scale_y_discrete(limits = rev(levels(a$item2))) +
    theme(axis.text.x = element_text(angle = 45, hjust = 0))
# Out:
# plot without title

# %%
options(repr.plot.width=12, repr.plot.height=12)
library(gplots)
a %>% heatmap.2(key = FALSE, keysize = 0.01, trace = "none", density.info = "none", na.color="black", dendrogram = "none", Rowv = FALSE, Colv = FALSE, col = redblue(75),
margins = c(10, 5), na.rm = TRUE, offsetRow = 0.00001)
# Out:
# plot without title
