# %% [markdown]
#   # 1 - Evaluate datasets on the anomaly algorithms

# %%
set.seed(20)

library(dplyr)
library(caret)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Loading required package: lattice
# Loading required package: ggplot2

# %%
evaluation_algorithms <- read.csv("results_evaluation/algorithms_metrics.csv")

# %% [markdown]
# - Casos em que no Random o precision e o recall são 0 e o F1 é NaN: Não existiu nenhum caso em que o random acertasse

# %%
evaluation_algorithms
# Out:
#     dataset        algorithm    variant     f1          precision   recall
# 1   dataset_aloi   DBSCAN       dbscan_0.3  0.07183342  0.03766637  0.77320955
# 2   dataset_aloi   DBSCAN       dbscan_0.5  0.07760393  0.04142224  0.61339523
# 3   dataset_aloi   DBSCAN       dbscan_0.7  0.08007986  0.04369402  0.47877984
# 4   dataset_aloi   DBSCAN       dbscan_0.9  0.08166263  0.04591626  0.36870027
# 5   dataset_aloi   DBSCAN       dbscan_1.1  0.08042446  0.04677856  0.28647215
# 6   dataset_aloi   LOF          lof_03      0.20689655  0.20689655  0.20689655
# 7   dataset_aloi   LOF          lof_05      0.20557029  0.20557029  0.20557029
# 8   dataset_aloi   LOF          lof_08      0.18435013  0.18435013  0.18435013
# 9   dataset_aloi   LOF          lof_14      0.15583554  0.15583554  0.15583554
# 10  dataset_aloi   LOF          lof_19      0.14854111  0.14854111  0.14854111
# 11  dataset_aloi   LOF          lof_25      0.14124668  0.14124668  0.14124668
# 12  dataset_aloi   LOF          lof_30      0.14058355  0.14058355  0.14058355
# 13  dataset_aloi   oneClassSVM  oneClassSVM 0.06599485  0.03499679  0.57758621
# 14  dataset_aloi   randomForest rf          0.15741306  0.98473282  0.08554377
# 15  dataset_aloi   random       random      0.03743316  0.03773585  0.03713528
# 16  dataset_iono   DBSCAN       dbscan_0.3  0.52830189  0.35897436  1.00000000
# 17  dataset_iono   DBSCAN       dbscan_0.5  0.52830189  0.35897436  1.00000000
# 18  dataset_iono   DBSCAN       dbscan_0.7  0.52830189  0.35897436  1.00000000
# 19  dataset_iono   DBSCAN       dbscan_0.9  0.52830189  0.35897436  1.00000000
# 20  dataset_iono   DBSCAN       dbscan_1.1  0.58333333  0.41176471  1.00000000
# 21  dataset_iono   LOF          lof_03      0.73809524  0.73809524  0.73809524
# 22  dataset_iono   LOF          lof_05      0.79365079  0.79365079  0.79365079
# 23  dataset_iono   LOF          lof_08      0.81746032  0.81746032  0.81746032
# 24  dataset_iono   LOF          lof_14      0.79365079  0.79365079  0.79365079
# 25  dataset_iono   LOF          lof_19      0.76984127  0.76984127  0.76984127
# 26  dataset_iono   LOF          lof_25      0.76190476  0.76190476  0.76190476
# 27  dataset_iono   LOF          lof_30      0.74603175  0.74603175  0.74603175
# 28  dataset_iono   oneClassSVM  oneClassSVM 0.67213115  0.51250000  0.97619048
# 29  dataset_iono   randomForest rf          0.89795918  0.92436975  0.87301587
# 30  dataset_iono   random       random      0.36434109  0.35606061  0.37301587
# ... ...            ...          ...         ...         ...         ...
# 286 dataset_stamps DBSCAN       dbscan_0.3  0.167115903 0.091176471 1.000000000
# 287 dataset_stamps DBSCAN       dbscan_0.5  0.167115903 0.091176471 1.000000000
# 288 dataset_stamps DBSCAN       dbscan_0.7  0.185628743 0.102310231 1.000000000
# 289 dataset_stamps DBSCAN       dbscan_0.9  0.228782288 0.129166667 1.000000000
# 290 dataset_stamps DBSCAN       dbscan_1.1  0.310000000 0.183431953 1.000000000
# 291 dataset_stamps LOF          lof_03      0.161290323 0.161290323 0.161290323
# 292 dataset_stamps LOF          lof_05      0.161290323 0.161290323 0.161290323
# 293 dataset_stamps LOF          lof_08      0.161290323 0.161290323 0.161290323
# 294 dataset_stamps LOF          lof_14      0.193548387 0.193548387 0.193548387
# 295 dataset_stamps LOF          lof_19      0.193548387 0.193548387 0.193548387
# 296 dataset_stamps LOF          lof_25      0.193548387 0.193548387 0.193548387
# 297 dataset_stamps LOF          lof_30      0.193548387 0.193548387 0.193548387
# 298 dataset_stamps oneClassSVM  oneClassSVM 0.278026906 0.161458333 1.000000000
# 299 dataset_stamps randomForest rf          0.813559322 0.857142857 0.774193548
# 300 dataset_stamps random       random      0.093750000 0.090909091 0.096774194
# 301 dataset_wilt   DBSCAN       dbscan_0.3  0.133489461 0.074186551 0.665369650
# 302 dataset_wilt   DBSCAN       dbscan_0.5  0.024229075 0.016897081 0.042801556
# 303 dataset_wilt   DBSCAN       dbscan_0.7  0.003663004 0.003460208 0.003891051
# 304 dataset_wilt   DBSCAN       dbscan_0.9           NA 0.000000000 0.000000000
# 305 dataset_wilt   DBSCAN       dbscan_1.1           NA 0.000000000 0.000000000
# 306 dataset_wilt   LOF          lof_03      0.136186770 0.136186770 0.136186770
# 307 dataset_wilt   LOF          lof_05      0.151750973 0.151750973 0.151750973
# 308 dataset_wilt   LOF          lof_08      0.124513619 0.124513619 0.124513619
# 309 dataset_wilt   LOF          lof_14      0.101167315 0.101167315 0.101167315
# 310 dataset_wilt   LOF          lof_19      0.073929961 0.073929961 0.073929961
# 311 dataset_wilt   LOF          lof_25      0.046692607 0.046692607 0.046692607
# 312 dataset_wilt   LOF          lof_30      0.038910506 0.038910506 0.038910506
# 313 dataset_wilt   oneClassSVM  oneClassSVM 0.049192929 0.027292111 0.249027237
# 314 dataset_wilt   randomForest rf          0.811279826 0.916666667 0.727626459
# 315 dataset_wilt   random       random      0.039761431 0.040650407 0.038910506

# %% [markdown]
# Que casos têm F1 a NA?

# %%
evaluation_algorithms %>% filter(is.na(f1)) %>% select(dataset, algorithm, variant)
# Out:
#    dataset         algorithm variant
# 1  dataset_kdd     random    random
# 2  dataset_pen     LOF       lof_25
# 3  dataset_pen     LOF       lof_30
# 4  dataset_pen     random    random
# 5  dataset_shuttle random    random
# 6  dataset_wbc     LOF       lof_03
# 7  dataset_wbc     LOF       lof_05
# 8  dataset_wbc     LOF       lof_08
# 9  dataset_wbc     LOF       lof_14
# 10 dataset_wbc     LOF       lof_19
# 11 dataset_wdbc    LOF       lof_03
# 12 dataset_wdbc    LOF       lof_05
# 13 dataset_wilt    DBSCAN    dbscan_0.9
# 14 dataset_wilt    DBSCAN    dbscan_1.1

# %% [markdown]
# Tirar os NA dos F1

# %%
evaluation_algorithms_no_NA <- evaluation_algorithms

# %%
evaluation_algorithms_no_NA[is.na(evaluation_algorithms_no_NA$f1), "f1"] <- 0

# %%
evaluation_algorithms_no_NA
# Out:
#     dataset        algorithm    variant     f1          precision   recall
# 1   dataset_aloi   DBSCAN       dbscan_0.3  0.07183342  0.03766637  0.77320955
# 2   dataset_aloi   DBSCAN       dbscan_0.5  0.07760393  0.04142224  0.61339523
# 3   dataset_aloi   DBSCAN       dbscan_0.7  0.08007986  0.04369402  0.47877984
# 4   dataset_aloi   DBSCAN       dbscan_0.9  0.08166263  0.04591626  0.36870027
# 5   dataset_aloi   DBSCAN       dbscan_1.1  0.08042446  0.04677856  0.28647215
# 6   dataset_aloi   LOF          lof_03      0.20689655  0.20689655  0.20689655
# 7   dataset_aloi   LOF          lof_05      0.20557029  0.20557029  0.20557029
# 8   dataset_aloi   LOF          lof_08      0.18435013  0.18435013  0.18435013
# 9   dataset_aloi   LOF          lof_14      0.15583554  0.15583554  0.15583554
# 10  dataset_aloi   LOF          lof_19      0.14854111  0.14854111  0.14854111
# 11  dataset_aloi   LOF          lof_25      0.14124668  0.14124668  0.14124668
# 12  dataset_aloi   LOF          lof_30      0.14058355  0.14058355  0.14058355
# 13  dataset_aloi   oneClassSVM  oneClassSVM 0.06599485  0.03499679  0.57758621
# 14  dataset_aloi   randomForest rf          0.15741306  0.98473282  0.08554377
# 15  dataset_aloi   random       random      0.03743316  0.03773585  0.03713528
# 16  dataset_iono   DBSCAN       dbscan_0.3  0.52830189  0.35897436  1.00000000
# 17  dataset_iono   DBSCAN       dbscan_0.5  0.52830189  0.35897436  1.00000000
# 18  dataset_iono   DBSCAN       dbscan_0.7  0.52830189  0.35897436  1.00000000
# 19  dataset_iono   DBSCAN       dbscan_0.9  0.52830189  0.35897436  1.00000000
# 20  dataset_iono   DBSCAN       dbscan_1.1  0.58333333  0.41176471  1.00000000
# 21  dataset_iono   LOF          lof_03      0.73809524  0.73809524  0.73809524
# 22  dataset_iono   LOF          lof_05      0.79365079  0.79365079  0.79365079
# 23  dataset_iono   LOF          lof_08      0.81746032  0.81746032  0.81746032
# 24  dataset_iono   LOF          lof_14      0.79365079  0.79365079  0.79365079
# 25  dataset_iono   LOF          lof_19      0.76984127  0.76984127  0.76984127
# 26  dataset_iono   LOF          lof_25      0.76190476  0.76190476  0.76190476
# 27  dataset_iono   LOF          lof_30      0.74603175  0.74603175  0.74603175
# 28  dataset_iono   oneClassSVM  oneClassSVM 0.67213115  0.51250000  0.97619048
# 29  dataset_iono   randomForest rf          0.89795918  0.92436975  0.87301587
# 30  dataset_iono   random       random      0.36434109  0.35606061  0.37301587
# ... ...            ...          ...         ...         ...         ...
# 286 dataset_stamps DBSCAN       dbscan_0.3  0.167115903 0.091176471 1.000000000
# 287 dataset_stamps DBSCAN       dbscan_0.5  0.167115903 0.091176471 1.000000000
# 288 dataset_stamps DBSCAN       dbscan_0.7  0.185628743 0.102310231 1.000000000
# 289 dataset_stamps DBSCAN       dbscan_0.9  0.228782288 0.129166667 1.000000000
# 290 dataset_stamps DBSCAN       dbscan_1.1  0.310000000 0.183431953 1.000000000
# 291 dataset_stamps LOF          lof_03      0.161290323 0.161290323 0.161290323
# 292 dataset_stamps LOF          lof_05      0.161290323 0.161290323 0.161290323
# 293 dataset_stamps LOF          lof_08      0.161290323 0.161290323 0.161290323
# 294 dataset_stamps LOF          lof_14      0.193548387 0.193548387 0.193548387
# 295 dataset_stamps LOF          lof_19      0.193548387 0.193548387 0.193548387
# 296 dataset_stamps LOF          lof_25      0.193548387 0.193548387 0.193548387
# 297 dataset_stamps LOF          lof_30      0.193548387 0.193548387 0.193548387
# 298 dataset_stamps oneClassSVM  oneClassSVM 0.278026906 0.161458333 1.000000000
# 299 dataset_stamps randomForest rf          0.813559322 0.857142857 0.774193548
# 300 dataset_stamps random       random      0.093750000 0.090909091 0.096774194
# 301 dataset_wilt   DBSCAN       dbscan_0.3  0.133489461 0.074186551 0.665369650
# 302 dataset_wilt   DBSCAN       dbscan_0.5  0.024229075 0.016897081 0.042801556
# 303 dataset_wilt   DBSCAN       dbscan_0.7  0.003663004 0.003460208 0.003891051
# 304 dataset_wilt   DBSCAN       dbscan_0.9  0.000000000 0.000000000 0.000000000
# 305 dataset_wilt   DBSCAN       dbscan_1.1  0.000000000 0.000000000 0.000000000
# 306 dataset_wilt   LOF          lof_03      0.136186770 0.136186770 0.136186770
# 307 dataset_wilt   LOF          lof_05      0.151750973 0.151750973 0.151750973
# 308 dataset_wilt   LOF          lof_08      0.124513619 0.124513619 0.124513619
# 309 dataset_wilt   LOF          lof_14      0.101167315 0.101167315 0.101167315
# 310 dataset_wilt   LOF          lof_19      0.073929961 0.073929961 0.073929961
# 311 dataset_wilt   LOF          lof_25      0.046692607 0.046692607 0.046692607
# 312 dataset_wilt   LOF          lof_30      0.038910506 0.038910506 0.038910506
# 313 dataset_wilt   oneClassSVM  oneClassSVM 0.049192929 0.027292111 0.249027237
# 314 dataset_wilt   randomForest rf          0.811279826 0.916666667 0.727626459
# 315 dataset_wilt   random       random      0.039761431 0.040650407 0.038910506

# %% [markdown]
# All the algorithms were better than random! Random forest seems to be better than almost any algorithm in most datasets. Precision seems to be the strongest point of this algorithm. LOF keeps outputing the same precision and recall

# %%
evaluation_algorithms_no_NA %>% group_by(dataset) %>% top_n(1, f1)
# Out:
#    dataset           algorithm    variant    f1        precision recall
# 1  dataset_aloi      LOF          lof_03     0.2068966 0.2068966 0.2068966
# 2  dataset_iono      randomForest rf         0.8979592 0.9243697 0.8730159
# 3  dataset_kdd       randomForest rf         0.8681319 0.9634146 0.7900000
# 4  dataset_pen       randomForest rf         0.6666667 1.0000000 0.5000000
# 5  dataset_shuttle   randomForest rf         0.9629630 0.9285714 1.0000000
# 6  dataset_waveform  LOF          lof_25     0.1500000 0.1500000 0.1500000
# 7  dataset_waveform  LOF          lof_30     0.1500000 0.1500000 0.1500000
# 8  dataset_wbc       randomForest rf         0.5882353 0.7142857 0.5000000
# 9  dataset_wdbc      randomForest rf         0.8235294 1.0000000 0.7000000
# 10 dataset_wpbc      DBSCAN       dbscan_0.3 0.3836735 0.2373737 1.0000000
# 11 dataset_wpbc      DBSCAN       dbscan_0.5 0.3836735 0.2373737 1.0000000
# 12 dataset_wpbc      DBSCAN       dbscan_0.7 0.3836735 0.2373737 1.0000000
# 13 dataset_wpbc      DBSCAN       dbscan_0.9 0.3836735 0.2373737 1.0000000
# 14 dataset_wpbc      DBSCAN       dbscan_1.1 0.3836735 0.2373737 1.0000000
# 15 dataset_ann       randomForest rf         0.9778598 0.9636364 0.9925094
# 16 dataset_arr       LOF          lof_19     0.3333333 0.3333333 0.3333333
# 17 dataset_arr       LOF          lof_25     0.3333333 0.3333333 0.3333333
# 18 dataset_arr       LOF          lof_30     0.3333333 0.3333333 0.3333333
# 19 dataset_cardio    randomForest rf         0.8828829 0.9397260 0.8325243
# 20 dataset_heart     randomForest rf         0.6101695 0.8181818 0.4864865
# 21 dataset_hepatitis randomForest rf         0.6666667 0.8750000 0.5384615
# 22 dataset_ads       randomForest rf         0.8908046 0.9451220 0.8423913
# 23 dataset_blocks    randomForest rf         0.8882295 0.8962076 0.8803922
# 24 dataset_parkinson randomForest rf         0.6000000 0.7500000 0.5000000
# 25 dataset_pima      randomForest rf         0.4550265 0.6718750 0.3440000
# 26 dataset_spam      randomForest rf         0.8694187 0.9297297 0.8164557
# 27 dataset_stamps    randomForest rf         0.8135593 0.8571429 0.7741935
# 28 dataset_wilt      randomForest rf         0.8112798 0.9166667 0.7276265

# %%
evaluation_algorithms_no_NA %>% filter(dataset == "dataset_wpbc")
# Out:
#    dataset      algorithm    variant     f1        precision recall
# 1  dataset_wpbc DBSCAN       dbscan_0.3  0.3836735 0.2373737 1.0000000
# 2  dataset_wpbc DBSCAN       dbscan_0.5  0.3836735 0.2373737 1.0000000
# 3  dataset_wpbc DBSCAN       dbscan_0.7  0.3836735 0.2373737 1.0000000
# 4  dataset_wpbc DBSCAN       dbscan_0.9  0.3836735 0.2373737 1.0000000
# 5  dataset_wpbc DBSCAN       dbscan_1.1  0.3836735 0.2373737 1.0000000
# 6  dataset_wpbc LOF          lof_03      0.1489362 0.1489362 0.1489362
# 7  dataset_wpbc LOF          lof_05      0.1276596 0.1276596 0.1276596
# 8  dataset_wpbc LOF          lof_08      0.1702128 0.1702128 0.1702128
# 9  dataset_wpbc LOF          lof_14      0.1702128 0.1702128 0.1702128
# 10 dataset_wpbc LOF          lof_19      0.1914894 0.1914894 0.1914894
# 11 dataset_wpbc LOF          lof_25      0.1702128 0.1702128 0.1702128
# 12 dataset_wpbc LOF          lof_30      0.1702128 0.1702128 0.1702128
# 13 dataset_wpbc oneClassSVM  oneClassSVM 0.3636364 0.2616822 0.5957447
# 14 dataset_wpbc randomForest rf          0.3606557 0.7857143 0.2340426
# 15 dataset_wpbc random       random      0.2772277 0.2592593 0.2978723

# %%
evaluation_algorithms_no_NA %>% filter(dataset == "dataset_waveform")
# Out:
#    dataset          algorithm    variant     f1         precision  recall
# 1  dataset_waveform DBSCAN       dbscan_0.3  0.05644934 0.02904444 1.00
# 2  dataset_waveform DBSCAN       dbscan_0.5  0.05644934 0.02904444 1.00
# 3  dataset_waveform DBSCAN       dbscan_0.7  0.05644934 0.02904444 1.00
# 4  dataset_waveform DBSCAN       dbscan_0.9  0.05644934 0.02904444 1.00
# 5  dataset_waveform DBSCAN       dbscan_1.1  0.05644934 0.02904444 1.00
# 6  dataset_waveform LOF          lof_03      0.11000000 0.11000000 0.11
# 7  dataset_waveform LOF          lof_05      0.12000000 0.12000000 0.12
# 8  dataset_waveform LOF          lof_08      0.11000000 0.11000000 0.11
# 9  dataset_waveform LOF          lof_14      0.12000000 0.12000000 0.12
# 10 dataset_waveform LOF          lof_19      0.14000000 0.14000000 0.14
# 11 dataset_waveform LOF          lof_25      0.15000000 0.15000000 0.15
# 12 dataset_waveform LOF          lof_30      0.15000000 0.15000000 0.15
# 13 dataset_waveform oneClassSVM  oneClassSVM 0.08733154 0.04615385 0.81
# 14 dataset_waveform randomForest rf          0.14814815 1.00000000 0.08
# 15 dataset_waveform random       random      0.02072539 0.02150538 0.02

# %%
evaluation_algorithms_no_NA %>% filter(dataset == "dataset_arr")
# Out:
#    dataset     algorithm    variant     f1        precision recall
# 1  dataset_arr DBSCAN       dbscan_0.3  0.1812081 0.0996310 1.0000000
# 2  dataset_arr DBSCAN       dbscan_0.5  0.1812081 0.0996310 1.0000000
# 3  dataset_arr DBSCAN       dbscan_0.7  0.1812081 0.0996310 1.0000000
# 4  dataset_arr DBSCAN       dbscan_0.9  0.1812081 0.0996310 1.0000000
# 5  dataset_arr DBSCAN       dbscan_1.1  0.1812081 0.0996310 1.0000000
# 6  dataset_arr LOF          lof_03      0.2962963 0.2962963 0.2962963
# 7  dataset_arr LOF          lof_05      0.2962963 0.2962963 0.2962963
# 8  dataset_arr LOF          lof_08      0.2962963 0.2962963 0.2962963
# 9  dataset_arr LOF          lof_14      0.2962963 0.2962963 0.2962963
# 10 dataset_arr LOF          lof_19      0.3333333 0.3333333 0.3333333
# 11 dataset_arr LOF          lof_25      0.3333333 0.3333333 0.3333333
# 12 dataset_arr LOF          lof_30      0.3333333 0.3333333 0.3333333
# 13 dataset_arr oneClassSVM  oneClassSVM 0.2711864 0.1600000 0.8888889
# 14 dataset_arr randomForest rf          0.2424242 0.6666667 0.1481481
# 15 dataset_arr random       random      0.1016949 0.0937500 0.1111111

# %% [markdown]
# # 2 - Evaluate datasets on the ensemble
